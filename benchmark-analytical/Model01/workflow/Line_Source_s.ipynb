# %%
import os
import shutil
from pathlib import Path

import pyvista as pv
import ogstools as ot
from ogstools.variables import Variable as ov

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from meshing import create_scylindre_mesh,create_rectangle_frac_mesh_v2
from functions_s import pd_lsrf_nb,step_rate_r,save_combined_mesh

# %% [markdown]
# # Path

# %%
OGS_PATH = None

if OGS_PATH is not None:
    os.environ["OGS_BIN_PATH"] = OGS_PATH
OUT_DIR = Path(os.environ.get("OGS_TESTRUNNER_OUT_DIR", "_out"))
MESH_DIR = OUT_DIR / "mesh"
shutil.rmtree(OUT_DIR, ignore_errors=True)
MESH_DIR.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# # Line-source

# %% [markdown]
# ## example preparation

# %%
cwd=Path.cwd()
newpath=cwd/"STIMTEC_example"
TESTSR= 'BH10_20180718_40.6'
dataex_f=pd.read_csv(newpath/"BH10_20180718_40.6_SR.csv",sep=",",header=0)
protocol=pd.read_csv(newpath/"protocol_SR.csv", sep=",",header=0)

# %%
#isolating Step-rate and preparing curve

fig8, ax=plt.subplots()

ax.set_xlabel("time / s")
ax.set_ylabel("Pressure / MPa, flowrate / lpm")
plt.title(f"test: {TESTSR}, steps")

ax.plot(dataex_f['Zeit [s]'],dataex_f['Pint_downhole [MPa]'],label="P int d")
for i in range (len(protocol)):
     ax.axvline(x=dataex_f.loc[protocol.iloc[i,0],'Zeit [s]'],ls="--",color="tab:red")
ax.plot(dataex_f['Zeit [s]'],dataex_f['Q_downhole [lpm]_s'],label="Q downhole_smoothed")

plt.legend()
plt.show()
#fig8.savefig(f"{TESTSR}_marks.pdf",format='pdf')

# %% [markdown]
# ## Line-source analytical

# %%
#data 
#average parameters from PPT
Dqp= 6.21e-1 #m**2/s
Tqp= 9.52E-07 #m**2/s
Sqp=1.53E-06  #-
re=8.5       # 8.63 m in reference
h=0.7         # m taken as interval length

c_t=Sqp/(1000*9.8*1.7*0.03)  # Pa-1
c_t=float(f"{c_t:.2e}")
kcal=(Tqp*1e-3)/(1000*9.8*1.7) #m**2
kcal=float(f"{kcal:.2e}")
print(f'Estimated total compressibility (Pa-1): {c_t},\nEstimated permeability (m^2): {kcal}')

ddict={"p_i":86316.0,
       "mu":1e-3 ,
       "B":1,
       "por":0.030,
       "c_t":c_t ,
       "r_w":0.038,
       'h': h
      }

delta_t=dataex_f['Zeit [s]'].values
tp=protocol['T_s [s]'].values
q_array=protocol['qs [m**3/s]'].values

rinv=np.sqrt(kcal*(tp[-1]-tp[0])/(ddict['por']*ddict['mu']*ddict['c_t']))
print("Investigation radius (m): ",f"{rinv:.2f}",'\n"Unperturbed" threshold (m): ', f"{4*rinv:.2f}")
# Out:
# Estimated total compressibility (Pa-1): 3.06e-09,
# Estimated permeability (m^2): 5.71e-14
# Investigation radius (m):  21.85
# "Unperturbed" threshold (m):  87.41

# %%
#evaluating best references k and re with varying r to re
rw=ddict['r_w']

r_val3=np.geomspace(ddict['r_w'],14,5).round(3) 

k_val3=5.14e-14 #np.geomspace(1e-14,1e-13,5) #5.5e-14#k_val2

print(f'k:{k_val3} m^2 {'\n'} r:{r_val3} m')

pwsr3= step_rate_r(pd_lsrf_nb, delta_t, tp, q_array, ddict, k_val3, r_val3)

line_labels13 = [f"r = {val:>5.3f} m" for val in r_val3]
# line_labels13 = [f"k = {val:>5.2e} m" for val in k_val3]

fig13, ax=plt.subplots()

ax.plot(delta_t, pwsr3/1e6, label=line_labels13)
ax.plot(dataex_f['Zeit [s]'],dataex_f['Pint_downhole [MPa]'],label="P int d", ls="--")

ax.set_xlabel("time / s")
ax.set_ylabel("Pressure / MPa")
plt.title(f"test: {TESTSR}, r-values, k={k_val3} m^2")

plt.legend()
plt.tight_layout()
plt.grid()
plt.show()
#fig13.savefig(f"lsrfa_fb_2D_{TESTSR}.pdf",format='pdf') #report figure
# Out:
# k:5.14e-14 m^2
#  r:[ 0.038  0.166  0.729  3.196 14.   ] m

# %% [markdown]
# # Fracture version

# %% [markdown]
# ## Meshing

# %%
MSH_FILE = MESH_DIR / "symmetric_cylinder_2D.msh"

r_well=0.038
thickness=ddict['h']  
mesh_size=thickness/4


create_rectangle_frac_mesh_v2(
    MSH_FILE,
    radius= 100,
    height= thickness,
    mesh_size= mesh_size,
    center_z=-40.6,
    r_well= r_well,      
    length=8.0
) 


meshes = ot.Meshes.from_gmsh(MSH_FILE, log=False)
for name, mesh in meshes.items():
    vtu_path = (MESH_DIR / f"rectangle_{name}.vtu").as_posix()
    pv.save_meshio(vtu_path, mesh)
    print(f"Saved {vtu_path}")

combined_vtu = (MESH_DIR / "combined_fracture_mesh.vtu").as_posix()
save_combined_mesh(MSH_FILE, combined_vtu)
# Out:
# Saved _out/mesh/rectangle_domain.vtu
# Saved _out/mesh/rectangle_intersection_point.vtu
# Saved _out/mesh/rectangle_fracture_tip.vtu
# Saved _out/mesh/rectangle_well.vtu
# Saved _out/mesh/rectangle_fracture.vtu
# Saved _out/mesh/rectangle_top.vtu
# Saved _out/mesh/rectangle_bottom.vtu
# Saved _out/mesh/rectangle_boundary_R.vtu
# Saved _out/mesh/rectangle_bulk_mesh.vtu
#
# Combined mesh saved to: _out/mesh/combined_fracture_mesh.vtu

# %%
mesh_to_plot=ot.mesh.read(combined_vtu)

fig14= ot.plot.contourf(mesh_to_plot,
    "MaterialIDs",
    figsize=(8, 6),
    dpi=100,
    cmap="tab20",
    alpha=0.3,
    linewidth=0,
)
ax = fig14.axes[0]
for i, (name, mesh) in enumerate(sorted(meshes.items())):
    if mesh.area:  
        continue
    
    ls, marker = ("-", "") if "boundary" in name else ("-", "o")
    
    ot.plot.line(
        mesh,
        ax=ax,
        color=f"C{i}",
        lw=2,
        ls=ls,
        marker=marker,
        markersize=8,
        label=name,
    )

#ax.set_aspect("equal")
ax.legend(ncol=2, loc='upper right',framealpha=0.6)
plt.show()

# %% [markdown]
# ## Running OGS base

# %%
# model = ot.Project(input_file="BH10_20180718_40.6_v2.prj")

# model.run_model(args=f"-o {OUT_DIR.as_posix()} -m {MESH_DIR.as_posix()}")

# %%
# !ogs ./BH10_20180718_40.6_v2.prj -m ./_out/mesh -o ./_out/
# Out:
# info: OGS started on 2026-04-13 21:25:35+0200 in serial mode.
# info: This is OpenGeoSys-6 version 6.5.7. Log version: 2, Log level: info.
# info: Eigen use 1 threads
# info: Reading project file BH10_20180718_40.6_v2.prj.
# info: readRasters ...
# info: readRasters done
# info: GroupBasedParameter: fracture_thickness
# info: ConstantParameter: p0
# info: ConstantParameter: p_tb
# info: ConstantParameter: pi_bd
# info: ConstantParameter: constant_porosity_parameter
# info: FunctionParameter: q_in
# info: Configure mesh 'rectangle_bottom' for boundary condition or source term.
# info: Configure mesh 'rectangle_top' for boundary condition or source term.
# info: Configure mesh 'rectangle_boundary_R' for boundary condition or source term.
# info: Configure mesh 'rectangle_well' for boundary condition or source term.
# info: Initialize processes.
# info: Time step #0 started. Time: 1750.009. Step size: 0.
# info: [time] Output of timestep 0 took 0.0597045 s.
# info: Time step #0 took 0.0638038 s.
# info: Solve processes.
# info: Time step #1 started. Time: 1750.1089999999999. Step size: 0.10000000000000001.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0152334 s.
# info: [time] Applying Dirichlet BCs took 0.0012594 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 49/10000
# info: 	 residual: 8.975445e-21
#
# info: [time] Linear solver took 0.0062884 s.
# info: Convergence criterion: |dx|=7.3920e+02, |x|=4.9155e+06, |dx|/|x|=1.5038e-04
# info: [time] Iteration #1 took 0.024346 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0091371 s.
# info: [time] Applying Dirichlet BCs took 0.000281 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 17/10000
# info: 	 residual: 7.328025e-21
#
# info: [time] Linear solver took 0.0006181 s.
# info: Convergence criterion: |dx|=9.3269e-10, |x|=4.9155e+06, |dx|/|x|=1.8974e-16
# info: [time] Iteration #2 took 0.0100826 s.
# info: [time] Solving process #0 took 0.0344567 s in time step #1
# info: [time] Time step #1 took 0.0371419 s.
# info: [time] Output of timestep 1 took 0.0192955 s.
# info: Time step #2 started. Time: 1750.259. Step size: 0.15000000000000002.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0094449 s.
# info: [time] Applying Dirichlet BCs took 0.0002765 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 61/10000
# info: 	 residual: 9.873749e-21
#
# info: [time] Linear solver took 0.0018817 s.
# info: Convergence criterion: |dx|=4.9353e+02, |x|=4.9155e+06, |dx|/|x|=1.0040e-04
# info: [time] Iteration #1 took 0.0116596 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.00926 s.
# info: [time] Applying Dirichlet BCs took 0.000253 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 21/10000
# info: 	 residual: 8.302329e-21
#
# info: [time] Linear solver took 0.0007335 s.
# info: Convergence criterion: |dx|=1.2087e-09, |x|=4.9155e+06, |dx|/|x|=2.4589e-16
# info: [time] Iteration #2 took 0.0102889 s.
# info: [time] Solving process #0 took 0.0219941 s in time step #2
# info: [time] Time step #2 took 0.0242547 s.
# info: [time] Output of timestep 2 took 0.0208641 s.
# info: Time step #3 started. Time: 1750.4839999999999. Step size: 0.22500000000000003.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0094685 s.
# info: [time] Applying Dirichlet BCs took 0.0003164 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 76/10000
# info: 	 residual: 9.590898e-21
#
# info: [time] Linear solver took 0.0023293 s.
# info: Convergence criterion: |dx|=3.4543e+02, |x|=4.9156e+06, |dx|/|x|=7.0273e-05
# info: [time] Iteration #1 took 0.0121729 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0092932 s.
# info: [time] Applying Dirichlet BCs took 0.0002764 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 26/10000
# info: 	 residual: 9.545975e-21
#
# info: [time] Linear solver took 0.0008964 s.
# info: Convergence criterion: |dx|=1.4396e-09, |x|=4.9156e+06, |dx|/|x|=2.9287e-16
# info: [time] Iteration #2 took 0.0105208 s.
# info: [time] Solving process #0 took 0.0227333 s in time step #3
# info: [time] Time step #3 took 0.024994 s.
# info: [time] Output of timestep 3 took 0.021051 s.
# info: Time step #4 started. Time: 1750.8215. Step size: 0.33750000000000002.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0111746 s.
# info: [time] Applying Dirichlet BCs took 0.0003035 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 94/10000
# info: 	 residual: 8.186893e-21
#
# info: [time] Linear solver took 0.0028872 s.
# info: Convergence criterion: |dx|=2.7585e+02, |x|=4.9156e+06, |dx|/|x|=5.6117e-05
# info: [time] Iteration #1 took 0.0144318 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.009139 s.
# info: [time] Applying Dirichlet BCs took 0.000286 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 33/10000
# info: 	 residual: 6.892819e-21
#
# info: [time] Linear solver took 0.0011041 s.
# info: Convergence criterion: |dx|=1.7124e-09, |x|=4.9156e+06, |dx|/|x|=3.4837e-16
# info: [time] Iteration #2 took 0.0105795 s.
# info: [time] Solving process #0 took 0.0250689 s in time step #4
# info: [time] Time step #4 took 0.0273494 s.
# info: [time] Output of timestep 4 took 0.020064 s.
# info: Time step #5 started. Time: 1751.3277499999999. Step size: 0.50625000000000009.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0094286 s.
# info: [time] Applying Dirichlet BCs took 0.0003188 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 115/10000
# info: 	 residual: 8.470657e-21
#
# info: [time] Linear solver took 0.0034678 s.
# info: Convergence criterion: |dx|=2.5130e+02, |x|=4.9156e+06, |dx|/|x|=5.1122e-05
# info: [time] Iteration #1 took 0.0132959 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0091521 s.
# info: [time] Applying Dirichlet BCs took 0.0002687 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 40/10000
# info: 	 residual: 8.196725e-21
#
# info: [time] Linear solver took 0.0012849 s.
# info: Convergence criterion: |dx|=2.3222e-09, |x|=4.9156e+06, |dx|/|x|=4.7240e-16
# info: [time] Iteration #2 took 0.0107511 s.
# info: [time] Solving process #0 took 0.0240959 s in time step #5
# info: [time] Time step #5 took 0.0263774 s.
# info: [time] Output of timestep 5 took 0.0192119 s.
# info: Time step #6 started. Time: 1752.087125. Step size: 0.75937500000000013.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0094462 s.
# info: [time] Applying Dirichlet BCs took 0.0002927 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 141/10000
# info: 	 residual: 8.395682e-21
#
# info: [time] Linear solver took 0.0041918 s.
# info: Convergence criterion: |dx|=2.4861e+02, |x|=4.9157e+06, |dx|/|x|=5.0574e-05
# info: [time] Iteration #1 took 0.0139946 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.009417 s.
# info: [time] Applying Dirichlet BCs took 0.0002735 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 49/10000
# info: 	 residual: 9.372553e-21
#
# info: [time] Linear solver took 0.0015894 s.
# info: Convergence criterion: |dx|=3.0479e-09, |x|=4.9157e+06, |dx|/|x|=6.2003e-16
# info: [time] Iteration #2 took 0.0113278 s.
# info: [time] Solving process #0 took 0.0253599 s in time step #6
# info: [time] Time step #6 took 0.0276152 s.
# info: [time] Output of timestep 6 took 0.0204778 s.
# info: Time step #7 started. Time: 1753.2261874999999. Step size: 1.1390625000000001.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0094502 s.
# info: [time] Applying Dirichlet BCs took 0.0003182 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 173/10000
# info: 	 residual: 8.814543e-21
#
# info: [time] Linear solver took 0.0051538 s.
# info: Convergence criterion: |dx|=2.5701e+02, |x|=4.9157e+06, |dx|/|x|=5.2283e-05
# info: [time] Iteration #1 took 0.014994 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0091905 s.
# info: [time] Applying Dirichlet BCs took 0.0002738 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 59/10000
# info: 	 residual: 9.842468e-21
#
# info: [time] Linear solver took 0.0018332 s.
# info: Convergence criterion: |dx|=3.2187e-09, |x|=4.9157e+06, |dx|/|x|=6.5478e-16
# info: [time] Iteration #2 took 0.0113527 s.
# info: [time] Solving process #0 took 0.0263994 s in time step #7
# info: [time] Time step #7 took 0.0286839 s.
# info: [time] Output of timestep 7 took 0.0195697 s.
# info: Time step #8 started. Time: 1754.93478125. Step size: 1.7085937500000001.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0097396 s.
# info: [time] Applying Dirichlet BCs took 0.0003173 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 211/10000
# info: 	 residual: 9.206479e-21
#
# info: [time] Linear solver took 0.0062183 s.
# info: Convergence criterion: |dx|=2.7225e+02, |x|=4.9158e+06, |dx|/|x|=5.5384e-05
# info: [time] Iteration #1 took 0.0163387 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0093405 s.
# info: [time] Applying Dirichlet BCs took 0.0002845 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 73/10000
# info: 	 residual: 8.670139e-21
#
# info: [time] Linear solver took 0.0022728 s.
# info: Convergence criterion: |dx|=4.3921e-09, |x|=4.9158e+06, |dx|/|x|=8.9348e-16
# info: [time] Iteration #2 took 0.0119447 s.
# info: [time] Solving process #0 took 0.0283391 s in time step #8
# info: [time] Time step #8 took 0.030603 s.
# info: [time] Output of timestep 8 took 0.0201825 s.
# info: Time step #9 started. Time: 1757.4976718749999. Step size: 2.5628906250000001.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0095157 s.
# info: [time] Applying Dirichlet BCs took 0.0003176 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 256/10000
# info: 	 residual: 8.675752e-21
#
# info: [time] Linear solver took 0.0075839 s.
# info: Convergence criterion: |dx|=2.9283e+02, |x|=4.9158e+06, |dx|/|x|=5.9569e-05
# info: [time] Iteration #1 took 0.0174778 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0090963 s.
# info: [time] Applying Dirichlet BCs took 0.0002871 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 89/10000
# info: 	 residual: 9.003245e-21
#
# info: [time] Linear solver took 0.0026855 s.
# info: Convergence criterion: |dx|=6.4256e-09, |x|=4.9158e+06, |dx|/|x|=1.3071e-15
# info: [time] Iteration #2 took 0.0121202 s.
# info: [time] Solving process #0 took 0.029642 s in time step #9
# info: [time] Time step #9 took 0.0319394 s.
# info: [time] Output of timestep 9 took 0.0192228 s.
# info: Time step #10 started. Time: 1761.3420078125. Step size: 3.8443359375000004.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0094797 s.
# info: [time] Applying Dirichlet BCs took 0.0002981 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 307/10000
# info: 	 residual: 9.462034e-21
#
# info: [time] Linear solver took 0.0089807 s.
# info: Convergence criterion: |dx|=3.1857e+02, |x|=4.9159e+06, |dx|/|x|=6.4804e-05
# info: [time] Iteration #1 took 0.0188246 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0089834 s.
# info: [time] Applying Dirichlet BCs took 0.000279 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 105/10000
# info: 	 residual: 9.535441e-21
#
# info: [time] Linear solver took 0.0031486 s.
# info: Convergence criterion: |dx|=8.3046e-09, |x|=4.9159e+06, |dx|/|x|=1.6893e-15
# info: [time] Iteration #2 took 0.0124643 s.
# info: [time] Solving process #0 took 0.031354 s in time step #10
# info: [time] Time step #10 took 0.0336176 s.
# info: [time] Output of timestep 10 took 0.0205355 s.
# info: Time step #11 started. Time: 1767.1085117187499. Step size: 5.7665039062500005.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0094476 s.
# info: [time] Applying Dirichlet BCs took 0.0003033 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 370/10000
# info: 	 residual: 9.910077e-21
#
# info: [time] Linear solver took 0.0108823 s.
# info: Convergence criterion: |dx|=3.5001e+02, |x|=4.9160e+06, |dx|/|x|=7.1199e-05
# info: [time] Iteration #1 took 0.0207173 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0099547 s.
# info: [time] Applying Dirichlet BCs took 0.0002789 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 125/10000
# info: 	 residual: 9.131324e-21
#
# info: [time] Linear solver took 0.0040716 s.
# info: Convergence criterion: |dx|=9.7467e-09, |x|=4.9160e+06, |dx|/|x|=1.9826e-15
# info: [time] Iteration #2 took 0.0143599 s.
# info: [time] Solving process #0 took 0.0351183 s in time step #11
# info: [time] Time step #11 took 0.0373766 s.
# info: [time] Output of timestep 11 took 0.0203667 s.
# info: Time step #12 started. Time: 1775.758267578125. Step size: 8.6497558593750004.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0097156 s.
# info: [time] Applying Dirichlet BCs took 0.0002946 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 450/10000
# info: 	 residual: 9.880787e-21
#
# info: [time] Linear solver took 0.0130812 s.
# info: Convergence criterion: |dx|=3.8783e+02, |x|=4.9161e+06, |dx|/|x|=7.8890e-05
# info: [time] Iteration #1 took 0.023155 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.009048 s.
# info: [time] Applying Dirichlet BCs took 0.0002726 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 154/10000
# info: 	 residual: 9.711589e-21
#
# info: [time] Linear solver took 0.0045682 s.
# info: Convergence criterion: |dx|=1.2727e-08, |x|=4.9161e+06, |dx|/|x|=2.5888e-15
# info: [time] Iteration #2 took 0.0139531 s.
# info: [time] Solving process #0 took 0.037151 s in time step #12
# info: [time] Time step #12 took 0.0393914 s.
# info: [time] Output of timestep 12 took 0.0204792 s.
# info: Time step #13 started. Time: 1785.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0092202 s.
# info: [time] Applying Dirichlet BCs took 0.0003317 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 480/10000
# info: 	 residual: 9.860791e-21
#
# info: [time] Linear solver took 0.0139253 s.
# info: Convergence criterion: |dx|=3.5014e+02, |x|=4.9162e+06, |dx|/|x|=7.1221e-05
# info: [time] Iteration #1 took 0.0235615 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0097948 s.
# info: [time] Applying Dirichlet BCs took 0.0002838 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 170/10000
# info: 	 residual: 9.374144e-21
#
# info: [time] Linear solver took 0.0050358 s.
# info: Convergence criterion: |dx|=1.2504e-08, |x|=4.9162e+06, |dx|/|x|=2.5433e-15
# info: [time] Iteration #2 took 0.0151652 s.
# info: [time] Solving process #0 took 0.0387753 s in time step #13
# info: [time] Time step #13 took 0.0411298 s.
# info: [time] Output of timestep 13 took 0.0194403 s.
# info: Time step #14 started. Time: 1795.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0090176 s.
# info: [time] Applying Dirichlet BCs took 0.000299 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 600/10000
# info: 	 residual: 9.774588e-21
#
# info: [time] Linear solver took 0.0174204 s.
# info: Convergence criterion: |dx|=5.1092e+05, |x|=5.0130e+06, |dx|/|x|=1.0192e-01
# info: [time] Iteration #1 took 0.0268107 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0096763 s.
# info: [time] Applying Dirichlet BCs took 0.0002817 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 166/10000
# info: 	 residual: 9.820739e-21
#
# info: [time] Linear solver took 0.0049101 s.
# info: Convergence criterion: |dx|=1.2045e-08, |x|=5.0130e+06, |dx|/|x|=2.4027e-15
# info: [time] Iteration #2 took 0.0149134 s.
# info: [time] Solving process #0 took 0.0417654 s in time step #14
# info: [time] Time step #14 took 0.0440615 s.
# info: [time] Output of timestep 14 took 0.0197203 s.
# info: Time step #15 started. Time: 1805.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0092199 s.
# info: [time] Applying Dirichlet BCs took 0.0003031 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 581/10000
# info: 	 residual: 9.295629e-21
#
# info: [time] Linear solver took 0.0169285 s.
# info: Convergence criterion: |dx|=1.3079e+05, |x|=5.0572e+06, |dx|/|x|=2.5863e-02
# info: [time] Iteration #1 took 0.0265317 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0093056 s.
# info: [time] Applying Dirichlet BCs took 0.0002795 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 170/10000
# info: 	 residual: 9.508504e-21
#
# info: [time] Linear solver took 0.0050232 s.
# info: Convergence criterion: |dx|=1.2168e-08, |x|=5.0572e+06, |dx|/|x|=2.4060e-15
# info: [time] Iteration #2 took 0.0146782 s.
# info: [time] Solving process #0 took 0.0412559 s in time step #15
# info: [time] Time step #15 took 0.0435684 s.
# info: [time] Output of timestep 15 took 0.0197432 s.
# info: Time step #16 started. Time: 1815.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0107907 s.
# info: [time] Applying Dirichlet BCs took 0.0004548 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 564/10000
# info: 	 residual: 9.872190e-21
#
# info: [time] Linear solver took 0.0252737 s.
# info: Convergence criterion: |dx|=8.2954e+04, |x|=5.0900e+06, |dx|/|x|=1.6297e-02
# info: [time] Iteration #1 took 0.0366169 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0137365 s.
# info: [time] Applying Dirichlet BCs took 0.000278 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 168/10000
# info: 	 residual: 9.935222e-21
#
# info: [time] Linear solver took 0.0053671 s.
# info: Convergence criterion: |dx|=1.0897e-08, |x|=5.0900e+06, |dx|/|x|=2.1409e-15
# info: [time] Iteration #2 took 0.0194834 s.
# info: [time] Solving process #0 took 0.0561585 s in time step #16
# info: [time] Time step #16 took 0.0595026 s.
# info: [time] Output of timestep 16 took 0.0205015 s.
# info: Time step #17 started. Time: 1825.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0091245 s.
# info: [time] Applying Dirichlet BCs took 0.0002959 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 556/10000
# info: 	 residual: 9.406265e-21
#
# info: [time] Linear solver took 0.0162369 s.
# info: Convergence criterion: |dx|=6.3290e+04, |x|=5.1175e+06, |dx|/|x|=1.2367e-02
# info: [time] Iteration #1 took 0.0257166 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0090211 s.
# info: [time] Applying Dirichlet BCs took 0.0002828 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 166/10000
# info: 	 residual: 9.902390e-21
#
# info: [time] Linear solver took 0.0049292 s.
# info: Convergence criterion: |dx|=1.5187e-08, |x|=5.1175e+06, |dx|/|x|=2.9677e-15
# info: [time] Iteration #2 took 0.0142838 s.
# info: [time] Solving process #0 took 0.0400412 s in time step #17
# info: [time] Time step #17 took 0.0423003 s.
# info: [time] Output of timestep 17 took 0.0208391 s.
# info: Time step #18 started. Time: 1835.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0091942 s.
# info: [time] Applying Dirichlet BCs took 0.0003104 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 552/10000
# info: 	 residual: 9.600918e-21
#
# info: [time] Linear solver took 0.0184004 s.
# info: Convergence criterion: |dx|=5.2142e+04, |x|=5.1416e+06, |dx|/|x|=1.0141e-02
# info: [time] Iteration #1 took 0.0279744 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0093448 s.
# info: [time] Applying Dirichlet BCs took 0.0002809 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 169/10000
# info: 	 residual: 9.853940e-21
#
# info: [time] Linear solver took 0.0050016 s.
# info: Convergence criterion: |dx|=1.3536e-08, |x|=5.1416e+06, |dx|/|x|=2.6327e-15
# info: [time] Iteration #2 took 0.0146931 s.
# info: [time] Solving process #0 took 0.0427136 s in time step #18
# info: [time] Time step #18 took 0.045001 s.
# info: [time] Output of timestep 18 took 0.0207839 s.
# info: Time step #19 started. Time: 1845.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0094985 s.
# info: [time] Applying Dirichlet BCs took 0.0003051 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 548/10000
# info: 	 residual: 9.664716e-21
#
# info: [time] Linear solver took 0.0159477 s.
# info: Convergence criterion: |dx|=4.4811e+04, |x|=5.1635e+06, |dx|/|x|=8.6784e-03
# info: [time] Iteration #1 took 0.0258291 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0099668 s.
# info: [time] Applying Dirichlet BCs took 0.0002966 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 171/10000
# info: 	 residual: 9.735163e-21
#
# info: [time] Linear solver took 0.0051522 s.
# info: Convergence criterion: |dx|=1.6177e-08, |x|=5.1635e+06, |dx|/|x|=3.1329e-15
# info: [time] Iteration #2 took 0.0154753 s.
# info: [time] Solving process #0 took 0.0413543 s in time step #19
# info: [time] Time step #19 took 0.0435835 s.
# info: [time] Output of timestep 19 took 0.0210963 s.
# info: Time step #20 started. Time: 1855.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0106684 s.
# info: [time] Applying Dirichlet BCs took 0.0002985 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 544/10000
# info: 	 residual: 9.589548e-21
#
# info: [time] Linear solver took 0.0162201 s.
# info: Convergence criterion: |dx|=3.9555e+04, |x|=5.1836e+06, |dx|/|x|=7.6307e-03
# info: [time] Iteration #1 took 0.0272617 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0098578 s.
# info: [time] Applying Dirichlet BCs took 0.0002762 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 169/10000
# info: 	 residual: 9.606723e-21
#
# info: [time] Linear solver took 0.0051157 s.
# info: Convergence criterion: |dx|=1.2328e-08, |x|=5.1836e+06, |dx|/|x|=2.3782e-15
# info: [time] Iteration #2 took 0.0153089 s.
# info: [time] Solving process #0 took 0.0426182 s in time step #20
# info: [time] Time step #20 took 0.0448839 s.
# info: [time] Output of timestep 20 took 0.0215579 s.
# info: Time step #21 started. Time: 1865.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0093041 s.
# info: [time] Applying Dirichlet BCs took 0.0002988 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 542/10000
# info: 	 residual: 9.517262e-21
#
# info: [time] Linear solver took 0.0179845 s.
# info: Convergence criterion: |dx|=3.5569e+04, |x|=5.2023e+06, |dx|/|x|=6.8372e-03
# info: [time] Iteration #1 took 0.0276609 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0091876 s.
# info: [time] Applying Dirichlet BCs took 0.0002803 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 168/10000
# info: 	 residual: 9.847729e-21
#
# info: [time] Linear solver took 0.004991 s.
# info: Convergence criterion: |dx|=1.2453e-08, |x|=5.2023e+06, |dx|/|x|=2.3936e-15
# info: [time] Iteration #2 took 0.0145122 s.
# info: [time] Solving process #0 took 0.0422143 s in time step #21
# info: [time] Time step #21 took 0.0444355 s.
# info: [time] Output of timestep 21 took 0.0211926 s.
# info: Time step #22 started. Time: 1875.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0093667 s.
# info: [time] Applying Dirichlet BCs took 0.0003105 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 539/10000
# info: 	 residual: 9.893677e-21
#
# info: [time] Linear solver took 0.0158086 s.
# info: Convergence criterion: |dx|=3.2426e+04, |x|=5.2199e+06, |dx|/|x|=6.2119e-03
# info: [time] Iteration #1 took 0.0255625 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0095422 s.
# info: [time] Applying Dirichlet BCs took 0.0002793 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 167/10000
# info: 	 residual: 9.923573e-21
#
# info: [time] Linear solver took 0.0049973 s.
# info: Convergence criterion: |dx|=1.3859e-08, |x|=5.2199e+06, |dx|/|x|=2.6550e-15
# info: [time] Iteration #2 took 0.0148678 s.
# info: [time] Solving process #0 took 0.0404783 s in time step #22
# info: [time] Time step #22 took 0.0427324 s.
# info: [time] Output of timestep 22 took 0.0218864 s.
# info: Time step #23 started. Time: 1885.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0094756 s.
# info: [time] Applying Dirichlet BCs took 0.0003331 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 537/10000
# info: 	 residual: 9.246850e-21
#
# info: [time] Linear solver took 0.0157372 s.
# info: Convergence criterion: |dx|=2.9872e+04, |x|=5.2366e+06, |dx|/|x|=5.7045e-03
# info: [time] Iteration #1 took 0.0256113 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0092871 s.
# info: [time] Applying Dirichlet BCs took 0.0003126 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 171/10000
# info: 	 residual: 9.047703e-21
#
# info: [time] Linear solver took 0.0050816 s.
# info: Convergence criterion: |dx|=1.5383e-08, |x|=5.2366e+06, |dx|/|x|=2.9376e-15
# info: [time] Iteration #2 took 0.014735 s.
# info: [time] Solving process #0 took 0.0403946 s in time step #23
# info: [time] Time step #23 took 0.0426976 s.
# info: [time] Output of timestep 23 took 0.0209086 s.
# info: Time step #24 started. Time: 1895.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0093051 s.
# info: [time] Applying Dirichlet BCs took 0.0002996 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 535/10000
# info: 	 residual: 9.242093e-21
#
# info: [time] Linear solver took 0.0155773 s.
# info: Convergence criterion: |dx|=2.7750e+04, |x|=5.2525e+06, |dx|/|x|=5.2832e-03
# info: [time] Iteration #1 took 0.0252471 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0090028 s.
# info: [time] Applying Dirichlet BCs took 0.0002696 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 165/10000
# info: 	 residual: 9.718449e-21
#
# info: [time] Linear solver took 0.0048837 s.
# info: Convergence criterion: |dx|=1.6730e-08, |x|=5.2525e+06, |dx|/|x|=3.1851e-15
# info: [time] Iteration #2 took 0.0142163 s.
# info: [time] Solving process #0 took 0.0395084 s in time step #24
# info: [time] Time step #24 took 0.0417402 s.
# info: [time] Output of timestep 24 took 0.020104 s.
# info: Time step #25 started. Time: 1905.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0096035 s.
# info: [time] Applying Dirichlet BCs took 0.0003145 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 533/10000
# info: 	 residual: 9.637788e-21
#
# info: [time] Linear solver took 0.0156441 s.
# info: Convergence criterion: |dx|=2.5953e+04, |x|=5.2676e+06, |dx|/|x|=4.9270e-03
# info: [time] Iteration #1 took 0.025633 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0092439 s.
# info: [time] Applying Dirichlet BCs took 0.000286 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 163/10000
# info: 	 residual: 9.654103e-21
#
# info: [time] Linear solver took 0.0048443 s.
# info: Convergence criterion: |dx|=1.3037e-08, |x|=5.2676e+06, |dx|/|x|=2.4749e-15
# info: [time] Iteration #2 took 0.0144198 s.
# info: [time] Solving process #0 took 0.0400925 s in time step #25
# info: [time] Time step #25 took 0.0423787 s.
# info: [time] Output of timestep 25 took 0.0195737 s.
# info: Time step #26 started. Time: 1915.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0091447 s.
# info: [time] Applying Dirichlet BCs took 0.0003185 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 601/10000
# info: 	 residual: 9.982609e-21
#
# info: [time] Linear solver took 0.0178969 s.
# info: Convergence criterion: |dx|=5.4293e+05, |x|=5.4613e+06, |dx|/|x|=9.9414e-02
# info: [time] Iteration #1 took 0.0274283 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0093433 s.
# info: [time] Applying Dirichlet BCs took 0.0002861 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 172/10000
# info: 	 residual: 9.576308e-21
#
# info: [time] Linear solver took 0.0050946 s.
# info: Convergence criterion: |dx|=1.5244e-08, |x|=5.4613e+06, |dx|/|x|=2.7912e-15
# info: [time] Iteration #2 took 0.01478 s.
# info: [time] Solving process #0 took 0.0422588 s in time step #26
# info: [time] Time step #26 took 0.0445025 s.
# info: [time] Output of timestep 26 took 0.0195647 s.
# info: Time step #27 started. Time: 1925.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0092004 s.
# info: [time] Applying Dirichlet BCs took 0.0003048 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 582/10000
# info: 	 residual: 9.832118e-21
#
# info: [time] Linear solver took 0.0169344 s.
# info: Convergence criterion: |dx|=1.5312e+05, |x|=5.5414e+06, |dx|/|x|=2.7632e-02
# info: [time] Iteration #1 took 0.0265037 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0092923 s.
# info: [time] Applying Dirichlet BCs took 0.0002904 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 169/10000
# info: 	 residual: 9.811213e-21
#
# info: [time] Linear solver took 0.0050117 s.
# info: Convergence criterion: |dx|=1.5308e-08, |x|=5.5414e+06, |dx|/|x|=2.7625e-15
# info: [time] Iteration #2 took 0.0146411 s.
# info: [time] Solving process #0 took 0.0411861 s in time step #27
# info: [time] Time step #27 took 0.0434096 s.
# info: [time] Output of timestep 27 took 0.0189654 s.
# info: Time step #28 started. Time: 1935.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0147303 s.
# info: [time] Applying Dirichlet BCs took 0.0004075 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 565/10000
# info: 	 residual: 9.850734e-21
#
# info: [time] Linear solver took 0.0165066 s.
# info: Convergence criterion: |dx|=1.0458e+05, |x|=5.6012e+06, |dx|/|x|=1.8672e-02
# info: [time] Iteration #1 took 0.0317638 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0100484 s.
# info: [time] Applying Dirichlet BCs took 0.0002746 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 173/10000
# info: 	 residual: 9.000857e-21
#
# info: [time] Linear solver took 0.00511 s.
# ...
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 178/10000
# info: 	 residual: 9.542066e-21
#
# info: [time] Linear solver took 0.0052606 s.
# info: Convergence criterion: |dx|=3.2772e-08, |x|=1.0736e+07, |dx|/|x|=3.0525e-15
# info: [time] Iteration #2 took 0.014874 s.
# info: [time] Solving process #0 took 0.0413128 s in time step #93
# info: [time] Time step #93 took 0.0437007 s.
# info: [time] Output of timestep 93 took 0.0192234 s.
# info: Time step #94 started. Time: 2595.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0093183 s.
# info: [time] Applying Dirichlet BCs took 0.0002147 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 574/10000
# info: 	 residual: 9.570798e-21
#
# info: [time] Linear solver took 0.0170723 s.
# info: Convergence criterion: |dx|=3.5639e+05, |x|=1.0483e+07, |dx|/|x|=3.3996e-02
# info: [time] Iteration #1 took 0.026658 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0090179 s.
# info: [time] Applying Dirichlet BCs took 0.0002505 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 176/10000
# info: 	 residual: 9.382985e-21
#
# info: [time] Linear solver took 0.0052213 s.
# info: Convergence criterion: |dx|=2.9238e-08, |x|=1.0483e+07, |dx|/|x|=2.7890e-15
# info: [time] Iteration #2 took 0.0145402 s.
# info: [time] Solving process #0 took 0.0412444 s in time step #94
# info: [time] Time step #94 took 0.0434966 s.
# info: [time] Output of timestep 94 took 0.0195513 s.
# info: Time step #95 started. Time: 2605.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0092687 s.
# info: [time] Applying Dirichlet BCs took 0.000328 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 569/10000
# info: 	 residual: 9.435965e-21
#
# info: [time] Linear solver took 0.0165272 s.
# info: Convergence criterion: |dx|=3.1351e+05, |x|=1.0261e+07, |dx|/|x|=3.0554e-02
# info: [time] Iteration #1 took 0.026184 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.009047 s.
# info: [time] Applying Dirichlet BCs took 0.0001953 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 176/10000
# info: 	 residual: 9.394897e-21
#
# info: [time] Linear solver took 0.0051553 s.
# info: Convergence criterion: |dx|=3.1722e-08, |x|=1.0261e+07, |dx|/|x|=3.0916e-15
# info: [time] Iteration #2 took 0.0144455 s.
# info: [time] Solving process #0 took 0.0407718 s in time step #95
# info: [time] Time step #95 took 0.0430242 s.
# info: [time] Output of timestep 95 took 0.0199798 s.
# info: Time step #96 started. Time: 2615.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0091437 s.
# info: [time] Applying Dirichlet BCs took 0.0002238 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 565/10000
# info: 	 residual: 9.476698e-21
#
# info: [time] Linear solver took 0.0163828 s.
# info: Convergence criterion: |dx|=2.7923e+05, |x|=1.0063e+07, |dx|/|x|=2.7749e-02
# info: [time] Iteration #1 took 0.0258143 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0090624 s.
# info: [time] Applying Dirichlet BCs took 0.0002487 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 169/10000
# info: 	 residual: 9.299143e-21
#
# info: [time] Linear solver took 0.0049757 s.
# info: Convergence criterion: |dx|=3.0593e-08, |x|=1.0063e+07, |dx|/|x|=3.0403e-15
# info: [time] Iteration #2 took 0.0143283 s.
# info: [time] Solving process #0 took 0.0401749 s in time step #96
# info: [time] Time step #96 took 0.0426923 s.
# info: [time] Output of timestep 96 took 0.0195174 s.
# info: Time step #97 started. Time: 2625.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0090992 s.
# info: [time] Applying Dirichlet BCs took 0.0002204 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 564/10000
# info: 	 residual: 9.368650e-21
#
# info: [time] Linear solver took 0.0165134 s.
# info: Convergence criterion: |dx|=2.5118e+05, |x|=9.8848e+06, |dx|/|x|=2.5411e-02
# info: [time] Iteration #1 took 0.0259379 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0097203 s.
# info: [time] Applying Dirichlet BCs took 0.0002461 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 175/10000
# info: 	 residual: 9.853063e-21
#
# info: [time] Linear solver took 0.0051704 s.
# info: Convergence criterion: |dx|=3.6469e-08, |x|=9.8848e+06, |dx|/|x|=3.6894e-15
# info: [time] Iteration #2 took 0.0151797 s.
# info: [time] Solving process #0 took 0.0411582 s in time step #97
# info: [time] Time step #97 took 0.0435918 s.
# info: [time] Output of timestep 97 took 0.0202545 s.
# info: Time step #98 started. Time: 2635.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0092836 s.
# info: [time] Applying Dirichlet BCs took 0.0003212 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 563/10000
# info: 	 residual: 9.854668e-21
#
# info: [time] Linear solver took 0.0166529 s.
# info: Convergence criterion: |dx|=2.2782e+05, |x|=9.7236e+06, |dx|/|x|=2.3430e-02
# info: [time] Iteration #1 took 0.0263353 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0101379 s.
# info: [time] Applying Dirichlet BCs took 0.0001968 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 175/10000
# info: 	 residual: 9.855186e-21
#
# info: [time] Linear solver took 0.0051372 s.
# info: Convergence criterion: |dx|=2.8977e-08, |x|=9.7236e+06, |dx|/|x|=2.9801e-15
# info: [time] Iteration #2 took 0.0155192 s.
# info: [time] Solving process #0 took 0.0420327 s in time step #98
# info: [time] Time step #98 took 0.0443504 s.
# info: [time] Output of timestep 98 took 0.0206861 s.
# info: Time step #99 started. Time: 2645.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0094526 s.
# info: [time] Applying Dirichlet BCs took 0.0002179 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 562/10000
# info: 	 residual: 9.810563e-21
#
# info: [time] Linear solver took 0.017385 s.
# info: Convergence criterion: |dx|=2.0806e+05, |x|=9.5765e+06, |dx|/|x|=2.1726e-02
# info: [time] Iteration #1 took 0.027133 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0092152 s.
# info: [time] Applying Dirichlet BCs took 0.0002421 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 177/10000
# info: 	 residual: 9.095084e-21
#
# info: [time] Linear solver took 0.0055461 s.
# info: Convergence criterion: |dx|=3.8675e-08, |x|=9.5765e+06, |dx|/|x|=4.0386e-15
# info: [time] Iteration #2 took 0.0150523 s.
# info: [time] Solving process #0 took 0.0422308 s in time step #99
# info: [time] Time step #99 took 0.044473 s.
# info: [time] Output of timestep 99 took 0.0196691 s.
# info: Time step #100 started. Time: 2655.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0105999 s.
# info: [time] Applying Dirichlet BCs took 0.0002971 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 558/10000
# info: 	 residual: 9.979909e-21
#
# info: [time] Linear solver took 0.0163002 s.
# info: Convergence criterion: |dx|=1.9114e+05, |x|=9.4416e+06, |dx|/|x|=2.0245e-02
# info: [time] Iteration #1 took 0.0272685 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0094704 s.
# info: [time] Applying Dirichlet BCs took 0.0002984 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 168/10000
# info: 	 residual: 9.832371e-21
#
# info: [time] Linear solver took 0.0050694 s.
# info: Convergence criterion: |dx|=2.2573e-08, |x|=9.4416e+06, |dx|/|x|=2.3908e-15
# info: [time] Iteration #2 took 0.0149076 s.
# info: [time] Solving process #0 took 0.0422472 s in time step #100
# info: [time] Time step #100 took 0.0444973 s.
# info: [time] Output of timestep 100 took 0.0193382 s.
# info: Time step #101 started. Time: 2665.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0092659 s.
# info: [time] Applying Dirichlet BCs took 0.0002878 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 556/10000
# info: 	 residual: 9.780122e-21
#
# info: [time] Linear solver took 0.0162344 s.
# info: Convergence criterion: |dx|=1.7650e+05, |x|=9.3172e+06, |dx|/|x|=1.8943e-02
# info: [time] Iteration #1 took 0.02585 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0091885 s.
# info: [time] Applying Dirichlet BCs took 0.0001957 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 167/10000
# info: 	 residual: 9.926268e-21
#
# info: [time] Linear solver took 0.0049682 s.
# info: Convergence criterion: |dx|=2.0461e-08, |x|=9.3172e+06, |dx|/|x|=2.1961e-15
# info: [time] Iteration #2 took 0.014407 s.
# info: [time] Solving process #0 took 0.0403922 s in time step #101
# info: [time] Time step #101 took 0.0426369 s.
# info: [time] Output of timestep 101 took 0.0201572 s.
# info: Time step #102 started. Time: 2669.8090000000002. Step size: 4.0507324218751819.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0090003 s.
# info: [time] Applying Dirichlet BCs took 0.0003062 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 358/10000
# info: 	 residual: 9.879305e-21
#
# info: [time] Linear solver took 0.0104288 s.
# info: Convergence criterion: |dx|=6.9236e+04, |x|=9.2686e+06, |dx|/|x|=7.4700e-03
# info: [time] Iteration #1 took 0.0197974 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0097987 s.
# info: [time] Applying Dirichlet BCs took 0.0001887 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 112/10000
# info: 	 residual: 9.448248e-21
#
# info: [time] Linear solver took 0.0033491 s.
# info: Convergence criterion: |dx|=1.3548e-08, |x|=9.2686e+06, |dx|/|x|=1.4618e-15
# info: [time] Iteration #2 took 0.0133772 s.
# info: [time] Solving process #0 took 0.0332935 s in time step #102
# info: [time] Time step #102 took 0.0355285 s.
# info: [time] Output of timestep 102 took 0.0196676 s.
# info: The whole computation of the time stepping took 102 steps, in which
# 	 the accepted steps are 102, and the rejected steps are 0.
#
# info: [time] Simulation completed. It took 6.57204 s.
# info: OGS completed on 2026-04-13 21:25:41+0200.

# %% [markdown]
# ## Results and visualisation base

# %%
pvd_path = Path("_out/BH10_20180718_40.6.pvd")
ms1 = ot.MeshSeries(pvd_path)
pressure=ot.variables.pressure
pressure= pressure.replace(output_unit="MPa")

# %%
y=-40.6
r_st=0.038 #equating the rgeo analytical
r_en=14

coords=np.array(np.geomspace([r_st,y,1e-18],[r_en,y,1e-18],5).round(3)) #extracting along x linearly
ms_probes1 = ms1.probe(points=coords)

labels = [f"OGS: r={pt[0]:>5.3f}, y={y}" for pt in coords]
timeogs1=ms_probes1.timevalues
pwsr3p= step_rate_r(pd_lsrf_nb, timeogs1, tp, q_array, ddict, k_val3, r_val3)

diff = pwsr3p - ms_probes1['pressure']
# Out:
# 100%|██████████| 103/103 [00:00<00:00, 206.15it/s]

# %% [markdown]
# ### Analytical and Numerical OGS comparison

# %%
fig15, axs= plt.subplots(nrows=1, ncols=2,figsize=[15,8], sharex=True)
ot.plot.line(ms_probes1,"time", pressure,ax=axs[0], color='k',fontsize=18,label=labels)
axs[0].plot(timeogs1, pwsr3p/1e6,color='tab:red', label=line_labels13) 
axs[1].plot(timeogs1, diff/1e6, label=line_labels13)

fig15.suptitle("Line-source analytical  - Numerical OGS Nodal") 
axs[1].set_xlabel("time / s")
axs[1].set_ylabel("diff / MPa")

axs[0].legend()
axs[1].legend()
axs[1].grid()
plt.tight_layout()

plt.show()

# %% [markdown]
# ## Running OGS example

# %%
# !ogs ./BH10_20180718_40.6_v3.prj -m ./_out/mesh -o ./_out/
# Out:
# info: OGS started on 2026-04-13 21:25:43+0200 in serial mode.
# info: This is OpenGeoSys-6 version 6.5.7. Log version: 2, Log level: info.
# info: Eigen use 1 threads
# info: Reading project file BH10_20180718_40.6_v3.prj.
# info: readRasters ...
# info: readRasters done
# info: GroupBasedParameter: fracture_thickness
# info: ConstantParameter: p0
# info: ConstantParameter: p_tb
# info: ConstantParameter: pi_bd
# info: ConstantParameter: constant_porosity_parameter
# info: FunctionParameter: q_in
# info: Configure mesh 'rectangle_bottom' for boundary condition or source term.
# info: Configure mesh 'rectangle_top' for boundary condition or source term.
# info: Configure mesh 'rectangle_boundary_R' for boundary condition or source term.
# info: Configure mesh 'rectangle_well' for boundary condition or source term.
# info: Initialize processes.
# info: Time step #0 started. Time: 1750.009. Step size: 0.
# info: [time] Output of timestep 0 took 0.0221189 s.
# info: Time step #0 took 0.0250108 s.
# info: Solve processes.
# info: Time step #1 started. Time: 1750.1089999999999. Step size: 0.10000000000000001.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0099547 s.
# info: [time] Applying Dirichlet BCs took 0.0003021 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 52/10000
# info: 	 residual: 3.158956e-21
#
# info: [time] Linear solver took 0.0016817 s.
# info: Convergence criterion: |dx|=1.7957e+03, |x|=4.9155e+06, |dx|/|x|=3.6531e-04
# info: [time] Iteration #1 took 0.0120211 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0094204 s.
# info: [time] Applying Dirichlet BCs took 0.0002983 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 12/10000
# info: 	 residual: 7.518504e-21
#
# info: [time] Linear solver took 0.0004739 s.
# info: Convergence criterion: |dx|=7.9158e-10, |x|=4.9155e+06, |dx|/|x|=1.6104e-16
# info: [time] Iteration #2 took 0.010243 s.
# info: [time] Solving process #0 took 0.0222956 s in time step #1
# info: [time] Time step #1 took 0.0246278 s.
# info: [time] Output of timestep 1 took 0.0190771 s.
# info: Time step #2 started. Time: 1750.259. Step size: 0.15000000000000002.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0091038 s.
# info: [time] Applying Dirichlet BCs took 0.0002805 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 56/10000
# info: 	 residual: 5.094823e-21
#
# info: [time] Linear solver took 0.0017457 s.
# info: Convergence criterion: |dx|=2.7006e+03, |x|=4.9156e+06, |dx|/|x|=5.4939e-04
# info: [time] Iteration #1 took 0.0111837 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0088726 s.
# info: [time] Applying Dirichlet BCs took 0.0003581 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 13/10000
# info: 	 residual: 8.397452e-21
#
# info: [time] Linear solver took 0.0005369 s.
# info: Convergence criterion: |dx|=8.8324e-10, |x|=4.9156e+06, |dx|/|x|=1.7968e-16
# info: [time] Iteration #2 took 0.0098325 s.
# info: [time] Solving process #0 took 0.0210542 s in time step #2
# info: [time] Time step #2 took 0.023368 s.
# info: [time] Output of timestep 2 took 0.0186339 s.
# info: Time step #3 started. Time: 1750.4839999999999. Step size: 0.22500000000000003.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0090678 s.
# info: [time] Applying Dirichlet BCs took 0.000298 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 59/10000
# info: 	 residual: 8.179583e-21
#
# info: [time] Linear solver took 0.0018491 s.
# info: Convergence criterion: |dx|=4.0287e+03, |x|=4.9157e+06, |dx|/|x|=8.1955e-04
# info: [time] Iteration #1 took 0.011272 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0089898 s.
# info: [time] Applying Dirichlet BCs took 0.0003217 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 18/10000
# info: 	 residual: 7.317636e-21
#
# info: [time] Linear solver took 0.0006454 s.
# info: Convergence criterion: |dx|=8.9444e-10, |x|=4.9157e+06, |dx|/|x|=1.8196e-16
# info: [time] Iteration #2 took 0.0100042 s.
# info: [time] Solving process #0 took 0.0213199 s in time step #3
# info: [time] Time step #3 took 0.0236294 s.
# info: [time] Output of timestep 3 took 0.0182784 s.
# info: Time step #4 started. Time: 1750.8215. Step size: 0.33750000000000002.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0094969 s.
# info: [time] Applying Dirichlet BCs took 0.0002871 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 62/10000
# info: 	 residual: 4.338018e-21
#
# info: [time] Linear solver took 0.0019298 s.
# info: Convergence criterion: |dx|=5.9380e+03, |x|=4.9159e+06, |dx|/|x|=1.2079e-03
# info: [time] Iteration #1 took 0.011767 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0090448 s.
# info: [time] Applying Dirichlet BCs took 0.0002956 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 22/10000
# info: 	 residual: 8.163386e-21
#
# info: [time] Linear solver took 0.0007768 s.
# info: Convergence criterion: |dx|=1.0163e-09, |x|=4.9159e+06, |dx|/|x|=2.0675e-16
# info: [time] Iteration #2 took 0.0101755 s.
# info: [time] Solving process #0 took 0.0219891 s in time step #4
# info: [time] Time step #4 took 0.024276 s.
# info: [time] Output of timestep 4 took 0.0186115 s.
# info: Time step #5 started. Time: 1751.3277499999999. Step size: 0.50625000000000009.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.009055 s.
# info: [time] Applying Dirichlet BCs took 0.0002854 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 64/10000
# info: 	 residual: 2.674742e-21
#
# info: [time] Linear solver took 0.0019931 s.
# info: Convergence criterion: |dx|=8.6362e+03, |x|=4.9162e+06, |dx|/|x|=1.7567e-03
# info: [time] Iteration #1 took 0.0113958 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0092041 s.
# info: [time] Applying Dirichlet BCs took 0.0003918 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 23/10000
# info: 	 residual: 9.487794e-21
#
# info: [time] Linear solver took 0.0007917 s.
# info: Convergence criterion: |dx|=9.3755e-10, |x|=4.9162e+06, |dx|/|x|=1.9071e-16
# info: [time] Iteration #2 took 0.0104375 s.
# info: [time] Solving process #0 took 0.021869 s in time step #5
# info: [time] Time step #5 took 0.0241423 s.
# info: [time] Output of timestep 5 took 0.0191764 s.
# info: Time step #6 started. Time: 1752.087125. Step size: 0.75937500000000013.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0091304 s.
# info: [time] Applying Dirichlet BCs took 0.0002871 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 64/10000
# info: 	 residual: 9.437743e-21
#
# info: [time] Linear solver took 0.0019807 s.
# info: Convergence criterion: |dx|=1.2369e+04, |x|=4.9166e+06, |dx|/|x|=2.5157e-03
# info: [time] Iteration #1 took 0.0114558 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0090229 s.
# info: [time] Applying Dirichlet BCs took 0.0003109 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 29/10000
# info: 	 residual: 9.667226e-21
#
# info: [time] Linear solver took 0.000961 s.
# info: Convergence criterion: |dx|=1.0245e-09, |x|=4.9166e+06, |dx|/|x|=2.0838e-16
# info: [time] Iteration #2 took 0.0103406 s.
# info: [time] Solving process #0 took 0.0218346 s in time step #6
# info: [time] Time step #6 took 0.0241114 s.
# info: [time] Output of timestep 6 took 0.0184138 s.
# info: Time step #7 started. Time: 1753.2261874999999. Step size: 1.1390625000000001.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0091139 s.
# info: [time] Applying Dirichlet BCs took 0.000292 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 65/10000
# info: 	 residual: 2.552278e-21
#
# info: [time] Linear solver took 0.0020086 s.
# info: Convergence criterion: |dx|=1.7381e+04, |x|=4.9173e+06, |dx|/|x|=3.5347e-03
# info: [time] Iteration #1 took 0.0114695 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0089592 s.
# info: [time] Applying Dirichlet BCs took 0.0002727 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 37/10000
# info: 	 residual: 9.599048e-21
#
# info: [time] Linear solver took 0.0012127 s.
# info: Convergence criterion: |dx|=1.0186e-09, |x|=4.9173e+06, |dx|/|x|=2.0715e-16
# info: [time] Iteration #2 took 0.0104936 s.
# info: [time] Solving process #0 took 0.0220044 s in time step #7
# info: [time] Time step #7 took 0.0242609 s.
# info: [time] Output of timestep 7 took 0.0183075 s.
# info: Time step #8 started. Time: 1754.93478125. Step size: 1.7085937500000001.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0091697 s.
# info: [time] Applying Dirichlet BCs took 0.0002751 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 64/10000
# info: 	 residual: 4.526629e-21
#
# info: [time] Linear solver took 0.0019748 s.
# info: Convergence criterion: |dx|=2.3838e+04, |x|=4.9185e+06, |dx|/|x|=4.8466e-03
# info: [time] Iteration #1 took 0.0114758 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0091445 s.
# info: [time] Applying Dirichlet BCs took 0.0002948 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 44/10000
# info: 	 residual: 9.062425e-21
#
# info: [time] Linear solver took 0.0014273 s.
# info: Convergence criterion: |dx|=1.7763e-09, |x|=4.9185e+06, |dx|/|x|=3.6115e-16
# info: [time] Iteration #2 took 0.0109251 s.
# info: [time] Solving process #0 took 0.0224486 s in time step #8
# info: [time] Time step #8 took 0.0247042 s.
# info: [time] Output of timestep 8 took 0.0196219 s.
# info: Time step #9 started. Time: 1757.4976718749999. Step size: 2.5628906250000001.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0093718 s.
# info: [time] Applying Dirichlet BCs took 0.0002795 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 63/10000
# info: 	 residual: 5.491023e-21
#
# info: [time] Linear solver took 0.0019434 s.
# info: Convergence criterion: |dx|=3.1665e+04, |x|=4.9203e+06, |dx|/|x|=6.4355e-03
# info: [time] Iteration #1 took 0.0116506 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0089274 s.
# info: [time] Applying Dirichlet BCs took 0.000265 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 43/10000
# info: 	 residual: 9.684382e-21
#
# info: [time] Linear solver took 0.0014055 s.
# info: Convergence criterion: |dx|=2.1484e-09, |x|=4.9203e+06, |dx|/|x|=4.3665e-16
# info: [time] Iteration #2 took 0.0106462 s.
# info: [time] Solving process #0 took 0.0223403 s in time step #9
# info: [time] Time step #9 took 0.0246402 s.
# info: [time] Output of timestep 9 took 0.0192544 s.
# info: Time step #10 started. Time: 1761.3420078125. Step size: 3.8443359375000004.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.009093 s.
# info: [time] Applying Dirichlet BCs took 0.0002844 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 62/10000
# info: 	 residual: 1.404426e-21
#
# info: [time] Linear solver took 0.0019581 s.
# info: Convergence criterion: |dx|=4.0315e+04, |x|=4.9230e+06, |dx|/|x|=8.1891e-03
# info: [time] Iteration #1 took 0.011407 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0090211 s.
# info: [time] Applying Dirichlet BCs took 0.0002715 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 48/10000
# info: 	 residual: 7.987571e-21
#
# info: [time] Linear solver took 0.0015163 s.
# info: Convergence criterion: |dx|=9.0713e-10, |x|=4.9230e+06, |dx|/|x|=1.8426e-16
# info: [time] Iteration #2 took 0.0108587 s.
# info: [time] Solving process #0 took 0.0223161 s in time step #10
# info: [time] Time step #10 took 0.0245566 s.
# info: [time] Output of timestep 10 took 0.0181431 s.
# info: Time step #11 started. Time: 1767.1085117187499. Step size: 5.7665039062500005.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.009311 s.
# info: [time] Applying Dirichlet BCs took 0.0003078 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 60/10000
# info: 	 residual: 6.329327e-21
#
# info: [time] Linear solver took 0.0018632 s.
# info: Convergence criterion: |dx|=4.8586e+04, |x|=4.9269e+06, |dx|/|x|=9.8614e-03
# info: [time] Iteration #1 took 0.011535 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0090911 s.
# info: [time] Applying Dirichlet BCs took 0.0003516 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 48/10000
# info: 	 residual: 7.683088e-21
#
# info: [time] Linear solver took 0.001511 s.
# info: Convergence criterion: |dx|=1.3069e-09, |x|=4.9269e+06, |dx|/|x|=2.6526e-16
# info: [time] Iteration #2 took 0.0110031 s.
# info: [time] Solving process #0 took 0.0225717 s in time step #11
# info: [time] Time step #11 took 0.0248391 s.
# info: [time] Output of timestep 11 took 0.0192253 s.
# info: Time step #12 started. Time: 1775.758267578125. Step size: 8.6497558593750004.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0092084 s.
# info: [time] Applying Dirichlet BCs took 0.0003153 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 63/10000
# info: 	 residual: 7.033385e-21
#
# info: [time] Linear solver took 0.0019887 s.
# info: Convergence criterion: |dx|=5.4773e+04, |x|=4.9321e+06, |dx|/|x|=1.1105e-02
# info: [time] Iteration #1 took 0.0115678 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0089555 s.
# info: [time] Applying Dirichlet BCs took 0.0002876 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 49/10000
# info: 	 residual: 9.252641e-21
#
# info: [time] Linear solver took 0.0015429 s.
# info: Convergence criterion: |dx|=2.1459e-09, |x|=4.9321e+06, |dx|/|x|=4.3509e-16
# info: [time] Iteration #2 took 0.0108304 s.
# info: [time] Solving process #0 took 0.0224358 s in time step #12
# info: [time] Time step #12 took 0.0247328 s.
# info: [time] Output of timestep 12 took 0.0184114 s.
# info: Time step #13 started. Time: 1785.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.009052 s.
# info: [time] Applying Dirichlet BCs took 0.0003474 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 66/10000
# info: 	 residual: 3.006589e-21
#
# info: [time] Linear solver took 0.0020577 s.
# info: Convergence criterion: |dx|=4.7253e+04, |x|=4.9372e+06, |dx|/|x|=9.5709e-03
# info: [time] Iteration #1 took 0.0115174 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0091678 s.
# info: [time] Applying Dirichlet BCs took 0.0002759 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 50/10000
# info: 	 residual: 7.510354e-21
#
# info: [time] Linear solver took 0.001557 s.
# info: Convergence criterion: |dx|=1.4381e-09, |x|=4.9372e+06, |dx|/|x|=2.9129e-16
# info: [time] Iteration #2 took 0.0110531 s.
# info: [time] Solving process #0 took 0.0226109 s in time step #13
# info: [time] Time step #13 took 0.0248882 s.
# info: [time] Output of timestep 13 took 0.0190733 s.
# info: Time step #14 started. Time: 1795.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0092562 s.
# info: [time] Applying Dirichlet BCs took 0.000308 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 110/10000
# info: 	 residual: 5.891827e-21
#
# info: [time] Linear solver took 0.0032998 s.
# info: Convergence criterion: |dx|=2.2116e+07, |x|=2.3118e+07, |dx|/|x|=9.5665e-01
# info: [time] Iteration #1 took 0.0129204 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0091059 s.
# info: [time] Applying Dirichlet BCs took 0.0004035 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 50/10000
# info: 	 residual: 8.583739e-21
#
# info: [time] Linear solver took 0.0017229 s.
# info: Convergence criterion: |dx|=4.8849e-09, |x|=2.3118e+07, |dx|/|x|=2.1130e-16
# info: [time] Iteration #2 took 0.0113 s.
# info: [time] Solving process #0 took 0.0242578 s in time step #14
# info: [time] Time step #14 took 0.0264975 s.
# info: [time] Output of timestep 14 took 0.0181982 s.
# info: Time step #15 started. Time: 1805.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0091565 s.
# info: [time] Applying Dirichlet BCs took 0.0003333 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 110/10000
# info: 	 residual: 5.477004e-21
#
# info: [time] Linear solver took 0.0033379 s.
# info: Convergence criterion: |dx|=1.5360e+07, |x|=3.8144e+07, |dx|/|x|=4.0268e-01
# info: [time] Iteration #1 took 0.012888 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0090783 s.
# info: [time] Applying Dirichlet BCs took 0.0003034 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 50/10000
# info: 	 residual: 8.739433e-21
#
# info: [time] Linear solver took 0.0016027 s.
# info: Convergence criterion: |dx|=1.6248e-08, |x|=3.8144e+07, |dx|/|x|=4.2597e-16
# info: [time] Iteration #2 took 0.0110368 s.
# info: [time] Solving process #0 took 0.023961 s in time step #15
# info: [time] Time step #15 took 0.0262496 s.
# info: [time] Output of timestep 15 took 0.0185809 s.
# info: Time step #16 started. Time: 1815.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0090385 s.
# info: [time] Applying Dirichlet BCs took 0.0003197 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 108/10000
# info: 	 residual: 7.015369e-21
#
# info: [time] Linear solver took 0.0037211 s.
# info: Convergence criterion: |dx|=1.1112e+07, |x|=4.8973e+07, |dx|/|x|=2.2690e-01
# info: [time] Iteration #1 took 0.0131413 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0090885 s.
# info: [time] Applying Dirichlet BCs took 0.0003064 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 50/10000
# info: 	 residual: 6.974281e-21
#
# info: [time] Linear solver took 0.0015778 s.
# info: Convergence criterion: |dx|=8.4569e-09, |x|=4.8973e+07, |dx|/|x|=1.7269e-16
# info: [time] Iteration #2 took 0.0110177 s.
# info: [time] Solving process #0 took 0.0241971 s in time step #16
# info: [time] Time step #16 took 0.0264154 s.
# info: [time] Output of timestep 16 took 0.0195562 s.
# info: Time step #17 started. Time: 1825.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0092626 s.
# info: [time] Applying Dirichlet BCs took 0.0003186 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 109/10000
# info: 	 residual: 6.159550e-21
#
# info: [time] Linear solver took 0.0034675 s.
# info: Convergence criterion: |dx|=8.3078e+06, |x|=5.6981e+07, |dx|/|x|=1.4580e-01
# info: [time] Iteration #1 took 0.0131086 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0091158 s.
# info: [time] Applying Dirichlet BCs took 0.000327 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 50/10000
# info: 	 residual: 8.837172e-21
#
# info: [time] Linear solver took 0.0017314 s.
# info: Convergence criterion: |dx|=4.7036e-08, |x|=5.6981e+07, |dx|/|x|=8.2547e-16
# info: [time] Iteration #2 took 0.0112211 s.
# info: [time] Solving process #0 took 0.0243711 s in time step #17
# info: [time] Time step #17 took 0.0266223 s.
# info: [time] Output of timestep 17 took 0.0182444 s.
# info: Time step #18 started. Time: 1835.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0092633 s.
# info: [time] Applying Dirichlet BCs took 0.0003319 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 109/10000
# info: 	 residual: 3.748826e-21
#
# info: [time] Linear solver took 0.0034879 s.
# info: Convergence criterion: |dx|=6.3991e+06, |x|=6.3064e+07, |dx|/|x|=1.0147e-01
# info: [time] Iteration #1 took 0.0131385 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.008912 s.
# info: [time] Applying Dirichlet BCs took 0.0003588 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 50/10000
# info: 	 residual: 9.763944e-21
#
# info: [time] Linear solver took 0.0018092 s.
# info: Convergence criterion: |dx|=4.0940e-08, |x|=6.3064e+07, |dx|/|x|=6.4918e-16
# info: [time] Iteration #2 took 0.0111374 s.
# info: [time] Solving process #0 took 0.0243151 s in time step #18
# info: [time] Time step #18 took 0.0265637 s.
# info: [time] Output of timestep 18 took 0.0186371 s.
# info: Time step #19 started. Time: 1845.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0090486 s.
# info: [time] Applying Dirichlet BCs took 0.0003133 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 101/10000
# info: 	 residual: 8.496870e-21
#
# info: [time] Linear solver took 0.0030706 s.
# info: Convergence criterion: |dx|=5.0667e+06, |x|=6.7803e+07, |dx|/|x|=7.4727e-02
# info: [time] Iteration #1 took 0.0124979 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0089663 s.
# info: [time] Applying Dirichlet BCs took 0.0002836 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 50/10000
# info: 	 residual: 7.452385e-21
#
# info: [time] Linear solver took 0.0015713 s.
# info: Convergence criterion: |dx|=2.3936e-08, |x|=6.7803e+07, |dx|/|x|=3.5303e-16
# info: [time] Iteration #2 took 0.010872 s.
# info: [time] Solving process #0 took 0.0234161 s in time step #19
# info: [time] Time step #19 took 0.0256685 s.
# info: [time] Output of timestep 19 took 0.0193884 s.
# info: Time step #20 started. Time: 1855.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0170451 s.
# info: [time] Applying Dirichlet BCs took 0.0003308 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 104/10000
# info: 	 residual: 7.522249e-21
#
# info: [time] Linear solver took 0.0038428 s.
# info: Convergence criterion: |dx|=4.1141e+06, |x|=7.1582e+07, |dx|/|x|=5.7475e-02
# info: [time] Iteration #1 took 0.0213093 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0100905 s.
# info: [time] Applying Dirichlet BCs took 0.0004401 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 50/10000
# info: 	 residual: 7.848686e-21
#
# info: [time] Linear solver took 0.001669 s.
# info: Convergence criterion: |dx|=3.7654e-08, |x|=7.1582e+07, |dx|/|x|=5.2602e-16
# info: [time] Iteration #2 took 0.0123032 s.
# info: [time] Solving process #0 took 0.0336679 s in time step #20
# info: [time] Time step #20 took 0.0360234 s.
# info: [time] Output of timestep 20 took 0.021585 s.
# info: Time step #21 started. Time: 1865.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0092984 s.
# info: [time] Applying Dirichlet BCs took 0.0003212 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 107/10000
# info: 	 residual: 8.007091e-21
#
# info: [time] Linear solver took 0.0032503 s.
# info: Convergence criterion: |dx|=3.4173e+06, |x|=7.4662e+07, |dx|/|x|=4.5770e-02
# info: [time] Iteration #1 took 0.0129347 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0090182 s.
# info: [time] Applying Dirichlet BCs took 0.0003076 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 50/10000
# info: 	 residual: 8.667081e-21
#
# info: [time] Linear solver took 0.0016392 s.
# info: Convergence criterion: |dx|=3.3436e-08, |x|=7.4662e+07, |dx|/|x|=4.4784e-16
# info: [time] Iteration #2 took 0.011016 s.
# info: [time] Solving process #0 took 0.023999 s in time step #21
# info: [time] Time step #21 took 0.0262974 s.
# info: [time] Output of timestep 21 took 0.0184307 s.
# info: Time step #22 started. Time: 1875.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0093314 s.
# info: [time] Applying Dirichlet BCs took 0.0002937 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 102/10000
# info: 	 residual: 8.127624e-21
#
# info: [time] Linear solver took 0.0030956 s.
# info: Convergence criterion: |dx|=2.8958e+06, |x|=7.7223e+07, |dx|/|x|=3.7499e-02
# info: [time] Iteration #1 took 0.0127819 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0092543 s.
# info: [time] Applying Dirichlet BCs took 0.0003009 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 50/10000
# info: 	 residual: 6.748992e-21
#
# info: [time] Linear solver took 0.0015621 s.
# info: Convergence criterion: |dx|=4.3407e-08, |x|=7.7223e+07, |dx|/|x|=5.6210e-16
# info: [time] Iteration #2 took 0.0111679 s.
# info: [time] Solving process #0 took 0.023984 s in time step #22
# info: [time] Time step #22 took 0.026231 s.
# info: [time] Output of timestep 22 took 0.0181464 s.
# info: Time step #23 started. Time: 1885.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0094685 s.
# info: [time] Applying Dirichlet BCs took 0.0003317 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 106/10000
# info: 	 residual: 8.230877e-21
#
# info: [time] Linear solver took 0.0032306 s.
# info: Convergence criterion: |dx|=2.4971e+06, |x|=7.9390e+07, |dx|/|x|=3.1453e-02
# info: [time] Iteration #1 took 0.0130956 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0092292 s.
# info: [time] Applying Dirichlet BCs took 0.000298 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 50/10000
# info: 	 residual: 7.988440e-21
#
# info: [time] Linear solver took 0.001593 s.
# info: Convergence criterion: |dx|=2.8163e-08, |x|=7.9390e+07, |dx|/|x|=3.5474e-16
# info: [time] Iteration #2 took 0.0111693 s.
# info: [time] Solving process #0 took 0.0243077 s in time step #23
# info: [time] Time step #23 took 0.0265529 s.
# info: [time] Output of timestep 23 took 0.0183475 s.
# info: Time step #24 started. Time: 1895.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0092844 s.
# info: [time] Applying Dirichlet BCs took 0.0003132 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 106/10000
# info: 	 residual: 8.518078e-21
#
# info: [time] Linear solver took 0.0032017 s.
# info: Convergence criterion: |dx|=2.1859e+06, |x|=8.1254e+07, |dx|/|x|=2.6902e-02
# info: [time] Iteration #1 took 0.0128589 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0089501 s.
# info: [time] Applying Dirichlet BCs took 0.0003084 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 48/10000
# info: 	 residual: 9.773143e-21
#
# info: [time] Linear solver took 0.0015493 s.
# info: Convergence criterion: |dx|=1.8615e-08, |x|=8.1254e+07, |dx|/|x|=2.2909e-16
# info: [time] Iteration #2 took 0.0108688 s.
# info: [time] Solving process #0 took 0.0237677 s in time step #24
# info: [time] Time step #24 took 0.0260917 s.
# info: [time] Output of timestep 24 took 0.0181785 s.
# info: Time step #25 started. Time: 1905.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0091439 s.
# info: [time] Applying Dirichlet BCs took 0.000305 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 106/10000
# info: 	 residual: 6.071855e-21
#
# info: [time] Linear solver took 0.0032385 s.
# info: Convergence criterion: |dx|=1.9382e+06, |x|=8.2879e+07, |dx|/|x|=2.3386e-02
# info: [time] Iteration #1 took 0.0127515 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0090605 s.
# info: [time] Applying Dirichlet BCs took 0.0003597 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 50/10000
# info: 	 residual: 8.380445e-21
#
# info: [time] Linear solver took 0.001773 s.
# info: Convergence criterion: |dx|=3.5162e-08, |x|=8.2879e+07, |dx|/|x|=4.2426e-16
# info: [time] Iteration #2 took 0.0112422 s.
# info: [time] Solving process #0 took 0.0240334 s in time step #25
# info: [time] Time step #25 took 0.0262709 s.
# info: [time] Output of timestep 25 took 0.018532 s.
# info: Time step #26 started. Time: 1915.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0092967 s.
# info: [time] Applying Dirichlet BCs took 0.0003049 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 109/10000
# info: 	 residual: 8.170813e-21
#
# info: [time] Linear solver took 0.0033082 s.
# info: Convergence criterion: |dx|=2.4135e+07, |x|=1.0630e+08, |dx|/|x|=2.2704e-01
# info: [time] Iteration #1 took 0.0129706 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.009143 s.
# info: [time] Applying Dirichlet BCs took 0.0002906 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 50/10000
# info: 	 residual: 9.774811e-21
#
# info: [time] Linear solver took 0.0015674 s.
# info: Convergence criterion: |dx|=2.2446e-08, |x|=1.0630e+08, |dx|/|x|=2.1116e-16
# info: [time] Iteration #2 took 0.011051 s.
# info: [time] Solving process #0 took 0.0240587 s in time step #26
# info: [time] Time step #26 took 0.0263205 s.
# info: [time] Output of timestep 26 took 0.0189357 s.
# info: Time step #27 started. Time: 1925.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0099847 s.
# info: [time] Applying Dirichlet BCs took 0.0003396 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 107/10000
# info: 	 residual: 7.948290e-21
#
# info: [time] Linear solver took 0.003281 s.
# info: Convergence criterion: |dx|=1.7118e+07, |x|=1.2338e+08, |dx|/|x|=1.3874e-01
# info: [time] Iteration #1 took 0.0136875 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0093407 s.
# info: [time] Applying Dirichlet BCs took 0.0003337 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 50/10000
# info: 	 residual: 8.495176e-21
#
# info: [time] Linear solver took 0.0016094 s.
# info: Convergence criterion: |dx|=5.1686e-08, |x|=1.2338e+08, |dx|/|x|=4.1891e-16
# info: [time] Iteration #2 took 0.0113484 s.
# info: [time] Solving process #0 took 0.025081 s in time step #27
# info: [time] Time step #27 took 0.0273588 s.
# info: [time] Output of timestep 27 took 0.0206361 s.
# info: Time step #28 started. Time: 1935.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0094405 s.
# info: [time] Applying Dirichlet BCs took 0.0003523 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 109/10000
# info: 	 residual: 7.831445e-21
#
# info: [time] Linear solver took 0.0032843 s.
# info: Convergence criterion: |dx|=1.2672e+07, |x|=1.3598e+08, |dx|/|x|=9.3187e-02
# info: [time] Iteration #1 took 0.0131418 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0090527 s.
# info: [time] Applying Dirichlet BCs took 0.0003149 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 51/10000
# info: 	 residual: 1.869347e-21
#
# info: [time] Linear solver took 0.0016648 s.
# info: Convergence criterion: |dx|=4.3244e-08, |x|=1.3598e+08, |dx|/|x|=3.1801e-16
# ...
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 51/10000
# info: 	 residual: 4.666148e-21
#
# info: [time] Linear solver took 0.0016557 s.
# info: Convergence criterion: |dx|=2.5765e-07, |x|=4.4217e+08, |dx|/|x|=5.8269e-16
# info: [time] Iteration #2 took 0.0111038 s.
# info: [time] Solving process #0 took 0.0241364 s in time step #93
# info: [time] Time step #93 took 0.0264177 s.
# info: [time] Output of timestep 93 took 0.0185132 s.
# info: Time step #94 started. Time: 2595.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0090367 s.
# info: [time] Applying Dirichlet BCs took 0.0002272 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 108/10000
# info: 	 residual: 7.635308e-21
#
# info: [time] Linear solver took 0.0032423 s.
# info: Convergence criterion: |dx|=4.1718e+07, |x|=4.0453e+08, |dx|/|x|=1.0313e-01
# info: [time] Iteration #1 took 0.0125574 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0089839 s.
# info: [time] Applying Dirichlet BCs took 0.000148 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 51/10000
# info: 	 residual: 3.300820e-21
#
# info: [time] Linear solver took 0.0015594 s.
# info: Convergence criterion: |dx|=1.3425e-07, |x|=4.0453e+08, |dx|/|x|=3.3188e-16
# info: [time] Iteration #2 took 0.0107365 s.
# info: [time] Solving process #0 took 0.0234757 s in time step #94
# info: [time] Time step #94 took 0.0257604 s.
# info: [time] Output of timestep 94 took 0.0187257 s.
# info: Time step #95 started. Time: 2605.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0092492 s.
# info: [time] Applying Dirichlet BCs took 0.0002383 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 110/10000
# info: 	 residual: 4.330953e-21
#
# info: [time] Linear solver took 0.0035356 s.
# info: Convergence criterion: |dx|=3.4487e+07, |x|=3.7331e+08, |dx|/|x|=9.2381e-02
# info: [time] Iteration #1 took 0.013078 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0089811 s.
# info: [time] Applying Dirichlet BCs took 0.0002607 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 51/10000
# info: 	 residual: 3.304434e-21
#
# info: [time] Linear solver took 0.0016206 s.
# info: Convergence criterion: |dx|=1.7639e-07, |x|=3.7331e+08, |dx|/|x|=4.7250e-16
# info: [time] Iteration #2 took 0.0109101 s.
# info: [time] Solving process #0 took 0.0240217 s in time step #95
# info: [time] Time step #95 took 0.026251 s.
# info: [time] Output of timestep 95 took 0.0183457 s.
# info: Time step #96 started. Time: 2615.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0090375 s.
# info: [time] Applying Dirichlet BCs took 0.0002094 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 110/10000
# info: 	 residual: 5.369965e-21
#
# info: [time] Linear solver took 0.0032755 s.
# info: Convergence criterion: |dx|=2.9009e+07, |x|=3.4695e+08, |dx|/|x|=8.3611e-02
# info: [time] Iteration #1 took 0.012577 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0089684 s.
# info: [time] Applying Dirichlet BCs took 0.0001454 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 51/10000
# info: 	 residual: 4.543105e-21
#
# info: [time] Linear solver took 0.0015753 s.
# info: Convergence criterion: |dx|=1.7434e-07, |x|=3.4695e+08, |dx|/|x|=5.0249e-16
# info: [time] Iteration #2 took 0.0107348 s.
# info: [time] Solving process #0 took 0.0234961 s in time step #96
# info: [time] Time step #96 took 0.0257744 s.
# info: [time] Output of timestep 96 took 0.0182821 s.
# info: Time step #97 started. Time: 2625.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0092233 s.
# info: [time] Applying Dirichlet BCs took 0.0002229 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 110/10000
# info: 	 residual: 5.693872e-21
#
# info: [time] Linear solver took 0.0032993 s.
# info: Convergence criterion: |dx|=2.4778e+07, |x|=3.2436e+08, |dx|/|x|=7.6390e-02
# info: [time] Iteration #1 took 0.0127999 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.009028 s.
# info: [time] Applying Dirichlet BCs took 0.0001727 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 51/10000
# info: 	 residual: 5.768117e-21
#
# info: [time] Linear solver took 0.0016143 s.
# info: Convergence criterion: |dx|=1.4816e-07, |x|=3.2436e+08, |dx|/|x|=4.5677e-16
# info: [time] Iteration #2 took 0.0108659 s.
# info: [time] Solving process #0 took 0.023835 s in time step #97
# info: [time] Time step #97 took 0.0260853 s.
# info: [time] Output of timestep 97 took 0.0193379 s.
# info: Time step #98 started. Time: 2635.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.009147 s.
# info: [time] Applying Dirichlet BCs took 0.0003165 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 110/10000
# info: 	 residual: 3.485074e-21
#
# info: [time] Linear solver took 0.0033197 s.
# info: Convergence criterion: |dx|=2.1450e+07, |x|=3.0475e+08, |dx|/|x|=7.0386e-02
# info: [time] Iteration #1 took 0.01284 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0091589 s.
# info: [time] Applying Dirichlet BCs took 0.0002619 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 51/10000
# info: 	 residual: 3.608540e-21
#
# info: [time] Linear solver took 0.0017375 s.
# info: Convergence criterion: |dx|=1.6191e-07, |x|=3.0475e+08, |dx|/|x|=5.3127e-16
# info: [time] Iteration #2 took 0.0112083 s.
# info: [time] Solving process #0 took 0.0241804 s in time step #98
# info: [time] Time step #98 took 0.0264118 s.
# info: [time] Output of timestep 98 took 0.0190262 s.
# info: Time step #99 started. Time: 2645.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0093156 s.
# info: [time] Applying Dirichlet BCs took 0.0002569 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 109/10000
# info: 	 residual: 6.291211e-21
#
# info: [time] Linear solver took 0.0032832 s.
# info: Convergence criterion: |dx|=1.8788e+07, |x|=2.8753e+08, |dx|/|x|=6.5344e-02
# info: [time] Iteration #1 took 0.0129182 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.009313 s.
# info: [time] Applying Dirichlet BCs took 0.0002747 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 51/10000
# info: 	 residual: 4.275598e-21
#
# info: [time] Linear solver took 0.0019239 s.
# info: Convergence criterion: |dx|=8.3753e-08, |x|=2.8753e+08, |dx|/|x|=2.9128e-16
# info: [time] Iteration #2 took 0.0115963 s.
# info: [time] Solving process #0 took 0.0247147 s in time step #99
# info: [time] Time step #99 took 0.0270376 s.
# info: [time] Output of timestep 99 took 0.0194476 s.
# info: Time step #100 started. Time: 2655.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0094325 s.
# info: [time] Applying Dirichlet BCs took 0.000224 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 110/10000
# info: 	 residual: 2.356065e-21
#
# info: [time] Linear solver took 0.0033258 s.
# info: Convergence criterion: |dx|=1.6625e+07, |x|=2.7226e+08, |dx|/|x|=6.1065e-02
# info: [time] Iteration #1 took 0.0130481 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0090056 s.
# info: [time] Applying Dirichlet BCs took 0.0001439 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 51/10000
# info: 	 residual: 5.101154e-21
#
# info: [time] Linear solver took 0.0015598 s.
# info: Convergence criterion: |dx|=1.3985e-07, |x|=2.7226e+08, |dx|/|x|=5.1367e-16
# info: [time] Iteration #2 took 0.0107427 s.
# info: [time] Solving process #0 took 0.023968 s in time step #100
# info: [time] Time step #100 took 0.0262356 s.
# info: [time] Output of timestep 100 took 0.0195957 s.
# info: Time step #101 started. Time: 2665.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0091998 s.
# info: [time] Applying Dirichlet BCs took 0.0002233 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 109/10000
# info: 	 residual: 5.252181e-21
#
# info: [time] Linear solver took 0.0032644 s.
# info: Convergence criterion: |dx|=1.4842e+07, |x|=2.5860e+08, |dx|/|x|=5.7395e-02
# info: [time] Iteration #1 took 0.0127496 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0089085 s.
# info: [time] Applying Dirichlet BCs took 0.0001476 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 51/10000
# info: 	 residual: 6.376205e-21
#
# info: [time] Linear solver took 0.0015633 s.
# info: Convergence criterion: |dx|=2.0968e-07, |x|=2.5860e+08, |dx|/|x|=8.1082e-16
# info: [time] Iteration #2 took 0.0106619 s.
# info: [time] Solving process #0 took 0.0235767 s in time step #101
# info: [time] Time step #101 took 0.0258197 s.
# info: [time] Output of timestep 101 took 0.0183623 s.
# info: Time step #102 started. Time: 2669.8090000000002. Step size: 4.0507324218751819.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0093912 s.
# info: [time] Applying Dirichlet BCs took 0.0002266 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 78/10000
# info: 	 residual: 9.312821e-21
#
# info: [time] Linear solver took 0.0023623 s.
# info: Convergence criterion: |dx|=5.7430e+06, |x|=2.5332e+08, |dx|/|x|=2.2671e-02
# info: [time] Iteration #1 took 0.0120356 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0089242 s.
# info: [time] Applying Dirichlet BCs took 0.0002526 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 50/10000
# info: 	 residual: 2.271831e-21
#
# info: [time] Linear solver took 0.0015745 s.
# info: Convergence criterion: |dx|=1.1933e-07, |x|=2.5332e+08, |dx|/|x|=4.7108e-16
# info: [time] Iteration #2 took 0.0107936 s.
# info: [time] Solving process #0 took 0.0228676 s in time step #102
# info: [time] Time step #102 took 0.0251426 s.
# info: [time] Output of timestep 102 took 0.0187856 s.
# info: The whole computation of the time stepping took 102 steps, in which
# 	 the accepted steps are 102, and the rejected steps are 0.
#
# info: [time] Simulation completed. It took 4.67227 s.
# info: OGS completed on 2026-04-13 21:25:48+0200.

# %% [markdown]
# ## Results and visualisation example

# %%
pvd_path = Path("_out/BH10_20180718_40.6.pvd")
ms2 = ot.MeshSeries(pvd_path)
pressure=ot.variables.pressure
pressure= pressure.replace(output_unit="MPa")

# %%
y=-40.6
r_st=0.038 #equating the rgeo analytical

coords=np.array([r_st,y,1e-18]).round(3) #extracting along x linearly
ms_probes2 = ms2.probe(points=coords)

labels2 = f"OGS (m): r={coords[0]:>5.3f}, y={y}"

exp_time = dataex_f['Zeit [s]'].values
exp_pres = dataex_f['Pint_downhole [MPa]'].values
timeogs2 = ms_probes2.timevalues  

ma_indices = [np.abs(exp_time - t).argmin() for t in timeogs2]
exp_at_OGS = exp_pres[ma_indices]
residual_pressure = exp_at_OGS.flatten() - ms_probes2['pressure'].flatten()
# Out:
# 100%|██████████| 103/103 [00:00<00:00, 212.34it/s]

# %% [markdown]
# ### Analytical and Numerical OGS comparison: example

# %%
fig16, axs= plt.subplots(nrows=1, ncols=2,figsize=[15,8], sharex=True)
ot.plot.line(ms_probes2,"time", pressure,ax=axs[0], color='k',fontsize=18,label=labels2)
axs[0].plot(dataex_f['Zeit [s]'],dataex_f['Pint_downhole [MPa]'],label=f"P int d at {rw}")
axs[1].plot(timeogs2, residual_pressure/1e6, label=line_labels13[0])


fig16.suptitle("Line-source analytical  - Numerical OGS Nodal") 
axs[1].set_xlabel("time / s")
axs[1].set_ylabel("diff / MPa")

axs[0].legend()
axs[1].legend()
axs[1].grid()
plt.tight_layout()

plt.show()

# %% [markdown]
# # Homogeneus media

# %% [markdown]
# ## Meshing

# %%
OGS_PATH = None

if OGS_PATH is not None:
    os.environ["OGS_BIN_PATH"] = OGS_PATH
OUT_DIR = Path(os.environ.get("OGS_TESTRUNNER_OUT_DIR", "_out_2"))
MESH_DIR = OUT_DIR / "mesh"
shutil.rmtree(OUT_DIR, ignore_errors=True)
MESH_DIR.mkdir(parents=True, exist_ok=True)

# %%
MSH_FILE = MESH_DIR / "symmetric_cylinder_2D.msh"

r_well=0.038
thickness=ddict['h']  
mesh_size=thickness/4

create_scylindre_mesh(
    MSH_FILE,
    radius= 100,
    thickness= thickness,
    mesh_size= mesh_size,
    r_well= 0.038,      # Starting radius (0 for line, >0 for finite)
    refine_size=0.1, 
    center_y= -40.6
) 

meshes = ot.Meshes.from_gmsh(MSH_FILE, log=False)
for name, mesh in meshes.items():
    vtu_path = (MESH_DIR / f"rectangle_{name}.vtu").as_posix()
    pv.save_meshio(vtu_path, mesh)
    print(f"Saved {vtu_path}")
# Out:
# Saved _out_2/mesh/rectangle_domain.vtu
# Saved _out_2/mesh/rectangle_top.vtu
# Saved _out_2/mesh/rectangle_boundary_R.vtu
# Saved _out_2/mesh/rectangle_bottom.vtu
# Saved _out_2/mesh/rectangle_well.vtu

# %% [markdown]
# ## Running OGS

# %%
# !ogs ./BH10_20180718_40.6_v1.prj -m ./_out_2/mesh -o ./_out_2/
# Out:
# info: OGS started on 2026-04-14 11:22:58+0200 in serial mode.
# info: This is OpenGeoSys-6 version 6.5.7. Log version: 2, Log level: info.
# info: Eigen use 1 threads
# info: Reading project file BH10_20180718_40.6_v1.prj.
# info: readRasters ...
# info: readRasters done
# info: ConstantParameter: p0
# info: ConstantParameter: p_tb
# info: ConstantParameter: pi_bd
# info: ConstantParameter: constant_porosity_parameter
# info: FunctionParameter: q_in
# info: Configure mesh 'rectangle_bottom' for boundary condition or source term.
# info: Configure mesh 'rectangle_top' for boundary condition or source term.
# info: Configure mesh 'rectangle_boundary_R' for boundary condition or source term.
# info: Configure mesh 'rectangle_well' for boundary condition or source term.
# info: Initialize processes.
# info: Time step #0 started. Time: 1750.009. Step size: 0.
# info: [time] Output of timestep 0 took 0.0538063 s.
# info: Time step #0 took 0.061373 s.
# info: Solve processes.
# info: Time step #1 started. Time: 1750.1089999999999. Step size: 0.10000000000000001.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0267134 s.
# info: [time] Applying Dirichlet BCs took 0.0008685 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 94/10000
# info: 	 residual: 8.105548e-21
#
# info: [time] Linear solver took 0.0089017 s.
# info: Convergence criterion: |dx|=1.3829e+03, |x|=5.5216e+06, |dx|/|x|=2.5045e-04
# info: [time] Iteration #1 took 0.0366338 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0243682 s.
# info: [time] Applying Dirichlet BCs took 0.0008388 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 28/10000
# info: 	 residual: 8.412742e-21
#
# info: [time] Linear solver took 0.0028684 s.
# info: Convergence criterion: |dx|=1.5435e-09, |x|=5.5216e+06, |dx|/|x|=2.7954e-16
# info: [time] Iteration #2 took 0.0281693 s.
# info: [time] Solving process #0 took 0.0649846 s in time step #1
# info: [time] Time step #1 took 0.0709651 s.
# info: [time] Output of timestep 1 took 0.0503518 s.
# info: Time step #2 started. Time: 1750.259. Step size: 0.15000000000000002.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0258045 s.
# info: [time] Applying Dirichlet BCs took 0.0007675 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 110/10000
# info: 	 residual: 8.744707e-21
#
# info: [time] Linear solver took 0.0102748 s.
# info: Convergence criterion: |dx|=6.5024e+02, |x|=5.5217e+06, |dx|/|x|=1.1776e-04
# info: [time] Iteration #1 took 0.0369685 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0263186 s.
# info: [time] Applying Dirichlet BCs took 0.0008509 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 38/10000
# info: 	 residual: 8.406337e-21
#
# info: [time] Linear solver took 0.0038003 s.
# info: Convergence criterion: |dx|=2.0653e-09, |x|=5.5217e+06, |dx|/|x|=3.7404e-16
# info: [time] Iteration #2 took 0.0310787 s.
# info: [time] Solving process #0 took 0.0682614 s in time step #2
# info: [time] Time step #2 took 0.0744144 s.
# info: [time] Output of timestep 2 took 0.0552827 s.
# info: Time step #3 started. Time: 1750.4839999999999. Step size: 0.22500000000000003.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0263598 s.
# info: [time] Applying Dirichlet BCs took 0.0007866 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 128/10000
# info: 	 residual: 9.641013e-21
#
# info: [time] Linear solver took 0.012164 s.
# info: Convergence criterion: |dx|=5.2712e+02, |x|=5.5218e+06, |dx|/|x|=9.5462e-05
# info: [time] Iteration #1 took 0.0394342 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0253255 s.
# info: [time] Applying Dirichlet BCs took 0.0008724 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 47/10000
# info: 	 residual: 9.785008e-21
#
# info: [time] Linear solver took 0.004635 s.
# info: Convergence criterion: |dx|=2.8420e-09, |x|=5.5218e+06, |dx|/|x|=5.1468e-16
# info: [time] Iteration #2 took 0.0309456 s.
# info: [time] Solving process #0 took 0.0706247 s in time step #3
# info: [time] Time step #3 took 0.0785029 s.
# info: [time] Output of timestep 3 took 0.0508842 s.
# info: Time step #4 started. Time: 1750.8215. Step size: 0.33750000000000002.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0259228 s.
# info: [time] Applying Dirichlet BCs took 0.0009416 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 152/10000
# info: 	 residual: 8.993942e-21
#
# info: [time] Linear solver took 0.01603 s.
# info: Convergence criterion: |dx|=4.9854e+02, |x|=5.5219e+06, |dx|/|x|=9.0283e-05
# info: [time] Iteration #1 took 0.0430481 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0296464 s.
# info: [time] Applying Dirichlet BCs took 0.0010429 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 56/10000
# info: 	 residual: 8.448897e-21
#
# info: [time] Linear solver took 0.0063833 s.
# info: Convergence criterion: |dx|=3.2869e-09, |x|=5.5219e+06, |dx|/|x|=5.9524e-16
# info: [time] Iteration #2 took 0.0372579 s.
# info: [time] Solving process #0 took 0.0805853 s in time step #4
# info: [time] Time step #4 took 0.0868771 s.
# info: [time] Output of timestep 4 took 0.0561439 s.
# info: Time step #5 started. Time: 1751.3277499999999. Step size: 0.50625000000000009.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0310932 s.
# info: [time] Applying Dirichlet BCs took 0.0008309 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 180/10000
# info: 	 residual: 7.894657e-21
#
# info: [time] Linear solver took 0.0172728 s.
# info: Convergence criterion: |dx|=5.0393e+02, |x|=5.5220e+06, |dx|/|x|=9.1259e-05
# info: [time] Iteration #1 took 0.0493541 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0275839 s.
# info: [time] Applying Dirichlet BCs took 0.0009044 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 74/10000
# info: 	 residual: 8.895757e-21
#
# info: [time] Linear solver took 0.0070866 s.
# info: Convergence criterion: |dx|=4.8240e-09, |x|=5.5220e+06, |dx|/|x|=8.7359e-16
# info: [time] Iteration #2 took 0.0356842 s.
# info: [time] Solving process #0 took 0.0852813 s in time step #5
# info: [time] Time step #5 took 0.0928131 s.
# info: [time] Output of timestep 5 took 0.0675694 s.
# info: Time step #6 started. Time: 1752.087125. Step size: 0.75937500000000013.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0279778 s.
# info: [time] Applying Dirichlet BCs took 0.0007767 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 210/10000
# info: 	 residual: 9.872661e-21
#
# info: [time] Linear solver took 0.0224948 s.
# info: Convergence criterion: |dx|=5.2686e+02, |x|=5.5221e+06, |dx|/|x|=9.5409e-05
# info: [time] Iteration #1 took 0.0514173 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0268899 s.
# info: [time] Applying Dirichlet BCs took 0.0008299 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 87/10000
# info: 	 residual: 9.100419e-21
#
# info: [time] Linear solver took 0.0111541 s.
# info: Convergence criterion: |dx|=5.1231e-09, |x|=5.5221e+06, |dx|/|x|=9.2775e-16
# info: [time] Iteration #2 took 0.0389994 s.
# info: [time] Solving process #0 took 0.0907039 s in time step #6
# info: [time] Time step #6 took 0.100146 s.
# info: [time] Output of timestep 6 took 0.113156 s.
# info: Time step #7 started. Time: 1753.2261874999999. Step size: 1.1390625000000001.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.04115 s.
# info: [time] Applying Dirichlet BCs took 0.0011966 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 245/10000
# info: 	 residual: 8.297505e-21
#
# info: [time] Linear solver took 0.0236147 s.
# info: Convergence criterion: |dx|=5.6113e+02, |x|=5.5223e+06, |dx|/|x|=1.0161e-04
# info: [time] Iteration #1 took 0.0662187 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0244322 s.
# info: [time] Applying Dirichlet BCs took 0.0008728 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 99/10000
# info: 	 residual: 9.208755e-21
#
# info: [time] Linear solver took 0.0094887 s.
# info: Convergence criterion: |dx|=6.1646e-09, |x|=5.5223e+06, |dx|/|x|=1.1163e-15
# info: [time] Iteration #2 took 0.034903 s.
# info: [time] Solving process #0 took 0.101386 s in time step #7
# info: [time] Time step #7 took 0.107328 s.
# info: [time] Output of timestep 7 took 0.0520021 s.
# info: Time step #8 started. Time: 1754.93478125. Step size: 1.7085937500000001.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0382167 s.
# info: [time] Applying Dirichlet BCs took 0.0012737 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 285/10000
# info: 	 residual: 9.466983e-21
#
# info: [time] Linear solver took 0.0324261 s.
# info: Convergence criterion: |dx|=6.0404e+02, |x|=5.5224e+06, |dx|/|x|=1.0938e-04
# info: [time] Iteration #1 took 0.0721007 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.025401 s.
# info: [time] Applying Dirichlet BCs took 0.0009306 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 126/10000
# info: 	 residual: 9.632700e-21
#
# info: [time] Linear solver took 0.0126379 s.
# info: Convergence criterion: |dx|=8.0081e-09, |x|=5.5224e+06, |dx|/|x|=1.4501e-15
# info: [time] Iteration #2 took 0.0390806 s.
# info: [time] Solving process #0 took 0.111433 s in time step #8
# info: [time] Time step #8 took 0.117894 s.
# info: [time] Output of timestep 8 took 0.0509471 s.
# info: Time step #9 started. Time: 1757.4976718749999. Step size: 2.5628906250000001.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0247064 s.
# info: [time] Applying Dirichlet BCs took 0.0007767 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 334/10000
# info: 	 residual: 9.432501e-21
#
# info: [time] Linear solver took 0.031743 s.
# info: Convergence criterion: |dx|=6.5428e+02, |x|=5.5227e+06, |dx|/|x|=1.1847e-04
# info: [time] Iteration #1 took 0.0573601 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0252064 s.
# info: [time] Applying Dirichlet BCs took 0.0009095 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 155/10000
# info: 	 residual: 9.426508e-21
#
# info: [time] Linear solver took 0.0144633 s.
# info: Convergence criterion: |dx|=1.0844e-08, |x|=5.5227e+06, |dx|/|x|=1.9635e-15
# info: [time] Iteration #2 took 0.0407025 s.
# info: [time] Solving process #0 took 0.0982973 s in time step #9
# info: [time] Time step #9 took 0.104259 s.
# info: [time] Output of timestep 9 took 0.051339 s.
# info: Time step #10 started. Time: 1761.3420078125. Step size: 3.8443359375000004.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0254567 s.
# info: [time] Applying Dirichlet BCs took 0.0008205 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 395/10000
# info: 	 residual: 9.830623e-21
#
# info: [time] Linear solver took 0.0359935 s.
# info: Convergence criterion: |dx|=7.1111e+02, |x|=5.5229e+06, |dx|/|x|=1.2876e-04
# info: [time] Iteration #1 took 0.06239 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0236374 s.
# info: [time] Applying Dirichlet BCs took 0.0008038 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 182/10000
# info: 	 residual: 9.837015e-21
#
# info: [time] Linear solver took 0.0173316 s.
# info: Convergence criterion: |dx|=1.2903e-08, |x|=5.5229e+06, |dx|/|x|=2.3362e-15
# info: [time] Iteration #2 took 0.0418755 s.
# info: [time] Solving process #0 took 0.104496 s in time step #10
# info: [time] Time step #10 took 0.110833 s.
# info: [time] Output of timestep 10 took 0.053447 s.
# info: Time step #11 started. Time: 1767.1085117187499. Step size: 5.7665039062500005.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0407996 s.
# info: [time] Applying Dirichlet BCs took 0.0018806 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 476/10000
# info: 	 residual: 8.967629e-21
#
# info: [time] Linear solver took 0.054285 s.
# info: Convergence criterion: |dx|=7.7405e+02, |x|=5.5232e+06, |dx|/|x|=1.4015e-04
# info: [time] Iteration #1 took 0.0971202 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0420378 s.
# info: [time] Applying Dirichlet BCs took 0.0014718 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 217/10000
# info: 	 residual: 9.638158e-21
#
# info: [time] Linear solver took 0.0332851 s.
# info: Convergence criterion: |dx|=2.4130e-08, |x|=5.5232e+06, |dx|/|x|=4.3689e-15
# info: [time] Iteration #2 took 0.0769794 s.
# info: [time] Solving process #0 took 0.174384 s in time step #11
# info: [time] Time step #11 took 0.184993 s.
# info: [time] Output of timestep 11 took 0.105828 s.
# info: Time step #12 started. Time: 1775.758267578125. Step size: 8.6497558593750004.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0410442 s.
# info: [time] Applying Dirichlet BCs took 0.0010522 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 570/10000
# info: 	 residual: 9.941644e-21
#
# info: [time] Linear solver took 0.0607596 s.
# info: Convergence criterion: |dx|=8.4271e+02, |x|=5.5235e+06, |dx|/|x|=1.5257e-04
# info: [time] Iteration #1 took 0.103045 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0403758 s.
# info: [time] Applying Dirichlet BCs took 0.0011569 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 258/10000
# info: 	 residual: 9.856403e-21
#
# info: [time] Linear solver took 0.0260177 s.
# info: Convergence criterion: |dx|=3.0245e-08, |x|=5.5235e+06, |dx|/|x|=5.4757e-15
# info: [time] Iteration #2 took 0.0677505 s.
# info: [time] Solving process #0 took 0.171071 s in time step #12
# info: [time] Time step #12 took 0.176931 s.
# info: [time] Output of timestep 12 took 0.0513236 s.
# info: Time step #13 started. Time: 1785.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0238306 s.
# info: [time] Applying Dirichlet BCs took 0.0008732 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 604/10000
# info: 	 residual: 9.720232e-21
#
# info: [time] Linear solver took 0.0546217 s.
# info: Convergence criterion: |dx|=7.4521e+02, |x|=5.5238e+06, |dx|/|x|=1.3491e-04
# info: [time] Iteration #1 took 0.0794691 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0238126 s.
# info: [time] Applying Dirichlet BCs took 0.0008485 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 278/10000
# info: 	 residual: 8.948890e-21
#
# info: [time] Linear solver took 0.02634 s.
# info: Convergence criterion: |dx|=2.9951e-08, |x|=5.5238e+06, |dx|/|x|=5.4222e-15
# info: [time] Iteration #2 took 0.0510969 s.
# info: [time] Solving process #0 took 0.130793 s in time step #13
# info: [time] Time step #13 took 0.13683 s.
# info: [time] Output of timestep 13 took 0.0522221 s.
# info: Time step #14 started. Time: 1795.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0240662 s.
# info: [time] Applying Dirichlet BCs took 0.0007624 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 803/10000
# info: 	 residual: 9.608474e-21
#
# info: [time] Linear solver took 0.0777713 s.
# info: Convergence criterion: |dx|=9.4438e+05, |x|=5.8139e+06, |dx|/|x|=1.6244e-01
# info: [time] Iteration #1 took 0.102709 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0287611 s.
# info: [time] Applying Dirichlet BCs took 0.0008302 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 268/10000
# info: 	 residual: 9.085474e-21
#
# info: [time] Linear solver took 0.0259465 s.
# info: Convergence criterion: |dx|=3.0378e-08, |x|=5.8139e+06, |dx|/|x|=5.2250e-15
# info: [time] Iteration #2 took 0.0556549 s.
# info: [time] Solving process #0 took 0.158579 s in time step #14
# info: [time] Time step #14 took 0.164508 s.
# info: [time] Output of timestep 14 took 0.0563112 s.
# info: Time step #15 started. Time: 1805.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0257828 s.
# info: [time] Applying Dirichlet BCs took 0.0008091 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 759/10000
# info: 	 residual: 9.888615e-21
#
# info: [time] Linear solver took 0.0701062 s.
# info: Convergence criterion: |dx|=2.8764e+05, |x|=5.9543e+06, |dx|/|x|=4.8307e-02
# info: [time] Iteration #1 took 0.096864 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0252328 s.
# info: [time] Applying Dirichlet BCs took 0.0009017 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 277/10000
# info: 	 residual: 9.615173e-21
#
# info: [time] Linear solver took 0.0289599 s.
# info: Convergence criterion: |dx|=4.4994e-08, |x|=5.9543e+06, |dx|/|x|=7.5566e-15
# info: [time] Iteration #2 took 0.0552028 s.
# info: [time] Solving process #0 took 0.152296 s in time step #15
# info: [time] Time step #15 took 0.158637 s.
# info: [time] Output of timestep 15 took 0.0580035 s.
# info: Time step #16 started. Time: 1815.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.028014 s.
# info: [time] Applying Dirichlet BCs took 0.0014121 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 724/10000
# info: 	 residual: 9.796589e-21
#
# info: [time] Linear solver took 0.0791173 s.
# info: Convergence criterion: |dx|=1.8063e+05, |x|=6.0531e+06, |dx|/|x|=2.9841e-02
# info: [time] Iteration #1 took 0.108733 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0291916 s.
# info: [time] Applying Dirichlet BCs took 0.0008128 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 274/10000
# info: 	 residual: 9.944550e-21
#
# info: [time] Linear solver took 0.0283137 s.
# info: Convergence criterion: |dx|=3.3109e-08, |x|=6.0531e+06, |dx|/|x|=5.4698e-15
# info: [time] Iteration #2 took 0.0584348 s.
# info: [time] Solving process #0 took 0.167401 s in time step #16
# info: [time] Time step #16 took 0.173225 s.
# info: [time] Output of timestep 16 took 0.0549456 s.
# info: Time step #17 started. Time: 1825.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0293038 s.
# info: [time] Applying Dirichlet BCs took 0.0007748 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 695/10000
# info: 	 residual: 9.776438e-21
#
# info: [time] Linear solver took 0.0714534 s.
# info: Convergence criterion: |dx|=1.3472e+05, |x|=6.1316e+06, |dx|/|x|=2.1972e-02
# info: [time] Iteration #1 took 0.101662 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0322189 s.
# info: [time] Applying Dirichlet BCs took 0.0011778 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 277/10000
# info: 	 residual: 9.888388e-21
#
# info: [time] Linear solver took 0.0594434 s.
# info: Convergence criterion: |dx|=4.1523e-08, |x|=6.1316e+06, |dx|/|x|=6.7721e-15
# info: [time] Iteration #2 took 0.0930778 s.
# info: [time] Solving process #0 took 0.19499 s in time step #17
# info: [time] Time step #17 took 0.20429 s.
# info: [time] Output of timestep 17 took 0.0749463 s.
# info: Time step #18 started. Time: 1835.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0251084 s.
# info: [time] Applying Dirichlet BCs took 0.0008742 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 698/10000
# info: 	 residual: 9.544568e-21
#
# info: [time] Linear solver took 0.0632447 s.
# info: Convergence criterion: |dx|=1.0867e+05, |x|=6.1977e+06, |dx|/|x|=1.7534e-02
# info: [time] Iteration #1 took 0.0893505 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0258289 s.
# info: [time] Applying Dirichlet BCs took 0.0008979 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 276/10000
# info: 	 residual: 9.354963e-21
#
# info: [time] Linear solver took 0.0324008 s.
# info: Convergence criterion: |dx|=2.6161e-08, |x|=6.1977e+06, |dx|/|x|=4.2211e-15
# info: [time] Iteration #2 took 0.0592607 s.
# info: [time] Solving process #0 took 0.148856 s in time step #18
# info: [time] Time step #18 took 0.158385 s.
# info: [time] Output of timestep 18 took 0.0585995 s.
# info: Time step #19 started. Time: 1845.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0284393 s.
# info: [time] Applying Dirichlet BCs took 0.0008159 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 697/10000
# info: 	 residual: 9.955120e-21
#
# info: [time] Linear solver took 0.063688 s.
# info: Convergence criterion: |dx|=9.1692e+04, |x|=6.2554e+06, |dx|/|x|=1.4658e-02
# info: [time] Iteration #1 took 0.0930908 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0264993 s.
# info: [time] Applying Dirichlet BCs took 0.0010358 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 274/10000
# info: 	 residual: 9.834188e-21
#
# info: [time] Linear solver took 0.0289596 s.
# info: Convergence criterion: |dx|=3.4215e-08, |x|=6.2554e+06, |dx|/|x|=5.4696e-15
# info: [time] Iteration #2 took 0.056666 s.
# info: [time] Solving process #0 took 0.150013 s in time step #19
# info: [time] Time step #19 took 0.156916 s.
# info: [time] Output of timestep 19 took 0.0577219 s.
# info: Time step #20 started. Time: 1855.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0298133 s.
# info: [time] Applying Dirichlet BCs took 0.0011881 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 689/10000
# info: 	 residual: 9.894756e-21
#
# info: [time] Linear solver took 0.0799567 s.
# info: Convergence criterion: |dx|=7.9662e+04, |x|=6.3069e+06, |dx|/|x|=1.2631e-02
# info: [time] Iteration #1 took 0.111157 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0269706 s.
# info: [time] Applying Dirichlet BCs took 0.0012293 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 273/10000
# info: 	 residual: 9.912164e-21
#
# info: [time] Linear solver took 0.0281624 s.
# info: Convergence criterion: |dx|=3.5403e-08, |x|=6.3069e+06, |dx|/|x|=5.6135e-15
# info: [time] Iteration #2 took 0.0565269 s.
# info: [time] Solving process #0 took 0.167977 s in time step #20
# info: [time] Time step #20 took 0.175114 s.
# info: [time] Output of timestep 20 took 0.0625133 s.
# info: Time step #21 started. Time: 1865.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0501419 s.
# info: [time] Applying Dirichlet BCs took 0.0016365 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 684/10000
# info: 	 residual: 9.153563e-21
#
# info: [time] Linear solver took 0.116716 s.
# info: Convergence criterion: |dx|=7.0650e+04, |x|=6.3535e+06, |dx|/|x|=1.1120e-02
# info: [time] Iteration #1 took 0.168864 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0482375 s.
# info: [time] Applying Dirichlet BCs took 0.0022633 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 277/10000
# info: 	 residual: 9.411366e-21
#
# info: [time] Linear solver took 0.0489336 s.
# info: Convergence criterion: |dx|=3.1533e-08, |x|=6.3535e+06, |dx|/|x|=4.9631e-15
# info: [time] Iteration #2 took 0.0998109 s.
# info: [time] Solving process #0 took 0.269029 s in time step #21
# info: [time] Time step #21 took 0.27501 s.
# info: [time] Output of timestep 21 took 0.0648377 s.
# info: Time step #22 started. Time: 1875.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0420643 s.
# info: [time] Applying Dirichlet BCs took 0.0011091 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 698/10000
# info: 	 residual: 9.540834e-21
#
# info: [time] Linear solver took 0.0732878 s.
# info: Convergence criterion: |dx|=6.3622e+04, |x|=6.3962e+06, |dx|/|x|=9.9468e-03
# info: [time] Iteration #1 took 0.116627 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0296037 s.
# info: [time] Applying Dirichlet BCs took 0.0009455 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 274/10000
# info: 	 residual: 9.150891e-21
#
# info: [time] Linear solver took 0.0258609 s.
# info: Convergence criterion: |dx|=3.7881e-08, |x|=6.3962e+06, |dx|/|x|=5.9224e-15
# info: [time] Iteration #2 took 0.0565715 s.
# info: [time] Solving process #0 took 0.173417 s in time step #22
# info: [time] Time step #22 took 0.179507 s.
# info: [time] Output of timestep 22 took 0.055823 s.
# info: Time step #23 started. Time: 1885.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0380096 s.
# info: [time] Applying Dirichlet BCs took 0.0013976 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 697/10000
# info: 	 residual: 9.824557e-21
#
# info: [time] Linear solver took 0.0747127 s.
# info: Convergence criterion: |dx|=5.7974e+04, |x|=6.4358e+06, |dx|/|x|=9.0080e-03
# info: [time] Iteration #1 took 0.114342 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0238703 s.
# info: [time] Applying Dirichlet BCs took 0.0009184 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 274/10000
# info: 	 residual: 9.592263e-21
#
# info: [time] Linear solver took 0.0291457 s.
# info: Convergence criterion: |dx|=4.6287e-08, |x|=6.4358e+06, |dx|/|x|=7.1921e-15
# info: [time] Iteration #2 took 0.0540762 s.
# info: [time] Solving process #0 took 0.168674 s in time step #23
# info: [time] Time step #23 took 0.178089 s.
# info: [time] Output of timestep 23 took 0.0609692 s.
# info: Time step #24 started. Time: 1895.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0297852 s.
# info: [time] Applying Dirichlet BCs took 0.0008033 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 684/10000
# info: 	 residual: 9.708251e-21
#
# info: [time] Linear solver took 0.0618837 s.
# info: Convergence criterion: |dx|=5.3325e+04, |x|=6.4727e+06, |dx|/|x|=8.2384e-03
# info: [time] Iteration #1 took 0.0926008 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0255615 s.
# info: [time] Applying Dirichlet BCs took 0.0009268 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 276/10000
# info: 	 residual: 9.860796e-21
#
# info: [time] Linear solver took 0.0267692 s.
# info: Convergence criterion: |dx|=4.5471e-08, |x|=6.4727e+06, |dx|/|x|=7.0250e-15
# info: [time] Iteration #2 took 0.0534307 s.
# info: [time] Solving process #0 took 0.146287 s in time step #24
# info: [time] Time step #24 took 0.152888 s.
# info: [time] Output of timestep 24 took 0.0685529 s.
# info: Time step #25 started. Time: 1905.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0367717 s.
# info: [time] Applying Dirichlet BCs took 0.0008245 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 684/10000
# info: 	 residual: 9.110692e-21
#
# info: [time] Linear solver took 0.0646888 s.
# info: Convergence criterion: |dx|=4.9426e+04, |x|=6.5074e+06, |dx|/|x|=7.5954e-03
# info: [time] Iteration #1 took 0.102446 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0292136 s.
# info: [time] Applying Dirichlet BCs took 0.0013852 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 270/10000
# info: 	 residual: 9.713885e-21
#
# info: [time] Linear solver took 0.0309809 s.
# info: Convergence criterion: |dx|=3.7255e-08, |x|=6.5074e+06, |dx|/|x|=5.7251e-15
# info: [time] Iteration #2 took 0.0617355 s.
# info: [time] Solving process #0 took 0.164429 s in time step #25
# info: [time] Time step #25 took 0.171039 s.
# info: [time] Output of timestep 25 took 0.0554195 s.
# info: Time step #26 started. Time: 1915.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0273389 s.
# info: [time] Applying Dirichlet BCs took 0.000884 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 806/10000
# info: 	 residual: 9.689461e-21
#
# info: [time] Linear solver took 0.0791084 s.
# info: Convergence criterion: |dx|=1.0187e+06, |x|=7.0582e+06, |dx|/|x|=1.4433e-01
# info: [time] Iteration #1 took 0.107485 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0246947 s.
# info: [time] Applying Dirichlet BCs took 0.0008863 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 273/10000
# info: 	 residual: 9.574503e-21
#
# info: [time] Linear solver took 0.0312267 s.
# info: Convergence criterion: |dx|=3.6346e-08, |x|=7.0582e+06, |dx|/|x|=5.1495e-15
# info: [time] Iteration #2 took 0.0569523 s.
# info: [time] Solving process #0 took 0.16468 s in time step #26
# info: [time] Time step #26 took 0.173523 s.
# info: [time] Output of timestep 26 took 0.0630578 s.
# info: Time step #27 started. Time: 1925.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0290596 s.
# info: [time] Applying Dirichlet BCs took 0.000808 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 762/10000
# info: 	 residual: 9.608627e-21
#
# info: [time] Linear solver took 0.0820958 s.
# info: Convergence criterion: |dx|=3.3710e+05, |x|=7.2947e+06, |dx|/|x|=4.6211e-02
# info: [time] Iteration #1 took 0.112124 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0253256 s.
# info: [time] Applying Dirichlet BCs took 0.0008384 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 269/10000
# info: 	 residual: 9.823749e-21
#
# info: [time] Linear solver took 0.0245321 s.
# info: Convergence criterion: |dx|=5.3113e-08, |x|=7.2947e+06, |dx|/|x|=7.2810e-15
# info: [time] Iteration #2 took 0.0508021 s.
# info: [time] Solving process #0 took 0.163172 s in time step #27
# info: [time] Time step #27 took 0.170569 s.
# info: [time] Output of timestep 27 took 0.0529369 s.
# info: Time step #28 started. Time: 1935.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0244681 s.
# info: [time] Applying Dirichlet BCs took 0.0007659 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 724/10000
# info: 	 residual: 9.605969e-21
#
# info: [time] Linear solver took 0.0689484 s.
# info: Convergence criterion: |dx|=2.2563e+05, |x|=7.4611e+06, |dx|/|x|=3.0241e-02
# info: [time] Iteration #1 took 0.0943309 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0252017 s.
# info: [time] Applying Dirichlet BCs took 0.0006718 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 269/10000
# info: 	 residual: 9.809840e-21
#
# info: [time] Linear solver took 0.0266783 s.
# info: Convergence criterion: |dx|=4.7305e-08, |x|=7.4611e+06, |dx|/|x|=6.3403e-15
# info: [time] Iteration #2 took 0.0526639 s.
# ...
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 279/10000
# info: 	 residual: 9.903773e-21
#
# info: [time] Linear solver took 0.0263238 s.
# info: Convergence criterion: |dx|=1.1149e-07, |x|=1.7109e+07, |dx|/|x|=6.5166e-15
# info: [time] Iteration #2 took 0.0520389 s.
# info: [time] Solving process #0 took 0.149877 s in time step #93
# info: [time] Time step #93 took 0.156486 s.
# info: [time] Output of timestep 93 took 0.0821191 s.
# info: Time step #94 started. Time: 2595.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0305604 s.
# info: [time] Applying Dirichlet BCs took 0.000668 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 735/10000
# info: 	 residual: 9.867045e-21
#
# info: [time] Linear solver took 0.0726156 s.
# info: Convergence criterion: |dx|=7.2636e+05, |x|=1.6494e+07, |dx|/|x|=4.4037e-02
# info: [time] Iteration #1 took 0.103973 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.024416 s.
# info: [time] Applying Dirichlet BCs took 0.0004784 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 273/10000
# info: 	 residual: 9.621396e-21
#
# info: [time] Linear solver took 0.0257214 s.
# info: Convergence criterion: |dx|=8.5813e-08, |x|=1.6494e+07, |dx|/|x|=5.2026e-15
# info: [time] Iteration #2 took 0.0507321 s.
# info: [time] Solving process #0 took 0.155082 s in time step #94
# info: [time] Time step #94 took 0.161051 s.
# info: [time] Output of timestep 94 took 0.0519685 s.
# info: Time step #95 started. Time: 2605.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0265481 s.
# info: [time] Applying Dirichlet BCs took 0.0008833 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 742/10000
# info: 	 residual: 9.932967e-21
#
# info: [time] Linear solver took 0.0706634 s.
# info: Convergence criterion: |dx|=6.3238e+05, |x|=1.5960e+07, |dx|/|x|=3.9624e-02
# info: [time] Iteration #1 took 0.0982462 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0257307 s.
# info: [time] Applying Dirichlet BCs took 0.0004797 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 282/10000
# info: 	 residual: 9.617884e-21
#
# info: [time] Linear solver took 0.0273136 s.
# info: Convergence criterion: |dx|=9.3266e-08, |x|=1.5960e+07, |dx|/|x|=5.8439e-15
# info: [time] Iteration #2 took 0.0536426 s.
# info: [time] Solving process #0 took 0.152307 s in time step #95
# info: [time] Time step #95 took 0.159044 s.
# info: [time] Output of timestep 95 took 0.0565707 s.
# info: Time step #96 started. Time: 2615.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0266973 s.
# info: [time] Applying Dirichlet BCs took 0.0006583 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 732/10000
# info: 	 residual: 9.810693e-21
#
# info: [time] Linear solver took 0.07196 s.
# info: Convergence criterion: |dx|=5.5805e+05, |x|=1.5488e+07, |dx|/|x|=3.6030e-02
# info: [time] Iteration #1 took 0.0994458 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0249254 s.
# info: [time] Applying Dirichlet BCs took 0.0006581 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 278/10000
# info: 	 residual: 9.625941e-21
#
# info: [time] Linear solver took 0.0278579 s.
# info: Convergence criterion: |dx|=8.8908e-08, |x|=1.5488e+07, |dx|/|x|=5.7403e-15
# info: [time] Iteration #2 took 0.0536141 s.
# info: [time] Solving process #0 took 0.15341 s in time step #96
# info: [time] Time step #96 took 0.159612 s.
# info: [time] Output of timestep 96 took 0.0569726 s.
# info: Time step #97 started. Time: 2625.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0288235 s.
# info: [time] Applying Dirichlet BCs took 0.0006173 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 730/10000
# info: 	 residual: 9.468674e-21
#
# info: [time] Linear solver took 0.0686745 s.
# info: Convergence criterion: |dx|=4.9786e+05, |x|=1.5069e+07, |dx|/|x|=3.3039e-02
# info: [time] Iteration #1 took 0.0982527 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0256613 s.
# info: [time] Applying Dirichlet BCs took 0.0004948 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 273/10000
# info: 	 residual: 9.709531e-21
#
# info: [time] Linear solver took 0.0256124 s.
# info: Convergence criterion: |dx|=1.1087e-07, |x|=1.5069e+07, |dx|/|x|=7.3577e-15
# info: [time] Iteration #2 took 0.0518835 s.
# info: [time] Solving process #0 took 0.150531 s in time step #97
# info: [time] Time step #97 took 0.157934 s.
# info: [time] Output of timestep 97 took 0.0559292 s.
# info: Time step #98 started. Time: 2635.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0266367 s.
# info: [time] Applying Dirichlet BCs took 0.0007596 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 729/10000
# info: 	 residual: 8.972612e-21
#
# info: [time] Linear solver took 0.0684676 s.
# info: Convergence criterion: |dx|=4.4817e+05, |x|=1.4692e+07, |dx|/|x|=3.0505e-02
# info: [time] Iteration #1 took 0.0959976 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0262813 s.
# info: [time] Applying Dirichlet BCs took 0.000699 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 276/10000
# info: 	 residual: 9.651916e-21
#
# info: [time] Linear solver took 0.0264751 s.
# info: Convergence criterion: |dx|=8.0153e-08, |x|=1.4692e+07, |dx|/|x|=5.4557e-15
# info: [time] Iteration #2 took 0.0535694 s.
# info: [time] Solving process #0 took 0.149979 s in time step #98
# info: [time] Time step #98 took 0.157018 s.
# info: [time] Output of timestep 98 took 0.0555885 s.
# info: Time step #99 started. Time: 2645.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0260281 s.
# info: [time] Applying Dirichlet BCs took 0.0007103 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 728/10000
# info: 	 residual: 9.419840e-21
#
# info: [time] Linear solver took 0.0687254 s.
# info: Convergence criterion: |dx|=4.0650e+05, |x|=1.4351e+07, |dx|/|x|=2.8326e-02
# info: [time] Iteration #1 took 0.0956126 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.02423 s.
# info: [time] Applying Dirichlet BCs took 0.0004855 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 278/10000
# info: 	 residual: 9.715558e-21
#
# info: [time] Linear solver took 0.0281865 s.
# info: Convergence criterion: |dx|=9.3626e-08, |x|=1.4351e+07, |dx|/|x|=6.5242e-15
# info: [time] Iteration #2 took 0.0530048 s.
# info: [time] Solving process #0 took 0.148973 s in time step #99
# info: [time] Time step #99 took 0.15499 s.
# info: [time] Output of timestep 99 took 0.0565539 s.
# info: Time step #100 started. Time: 2655.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0247227 s.
# info: [time] Applying Dirichlet BCs took 0.0006664 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 728/10000
# info: 	 residual: 9.257306e-21
#
# info: [time] Linear solver took 0.0692801 s.
# info: Convergence criterion: |dx|=3.7109e+05, |x|=1.4040e+07, |dx|/|x|=2.6432e-02
# info: [time] Iteration #1 took 0.0947948 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0241233 s.
# info: [time] Applying Dirichlet BCs took 0.0004761 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 273/10000
# info: 	 residual: 9.806819e-21
#
# info: [time] Linear solver took 0.026715 s.
# info: Convergence criterion: |dx|=4.4823e-08, |x|=1.4040e+07, |dx|/|x|=3.1926e-15
# info: [time] Iteration #2 took 0.0514163 s.
# info: [time] Solving process #0 took 0.14651 s in time step #100
# info: [time] Time step #100 took 0.152858 s.
# info: [time] Output of timestep 100 took 0.0557652 s.
# info: Time step #101 started. Time: 2665.758267578125. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0298392 s.
# info: [time] Applying Dirichlet BCs took 0.0006249 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 727/10000
# info: 	 residual: 9.130988e-21
#
# info: [time] Linear solver took 0.0684913 s.
# info: Convergence criterion: |dx|=3.4066e+05, |x|=1.3755e+07, |dx|/|x|=2.4766e-02
# info: [time] Iteration #1 took 0.0990888 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.025783 s.
# info: [time] Applying Dirichlet BCs took 0.0005342 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 275/10000
# info: 	 residual: 9.425306e-21
#
# info: [time] Linear solver took 0.0265916 s.
# info: Convergence criterion: |dx|=5.9312e-08, |x|=1.3755e+07, |dx|/|x|=4.3120e-15
# info: [time] Iteration #2 took 0.0530094 s.
# info: [time] Solving process #0 took 0.152459 s in time step #101
# info: [time] Time step #101 took 0.159129 s.
# info: [time] Output of timestep 101 took 0.0552828 s.
# info: Time step #102 started. Time: 2669.8090000000002. Step size: 4.0507324218751819.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0264325 s.
# info: [time] Applying Dirichlet BCs took 0.0008693 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 490/10000
# info: 	 residual: 9.465188e-21
#
# info: [time] Linear solver took 0.0468603 s.
# info: Convergence criterion: |dx|=1.3331e+05, |x|=1.3644e+07, |dx|/|x|=9.7705e-03
# info: [time] Iteration #1 took 0.0742953 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.02467 s.
# info: [time] Applying Dirichlet BCs took 0.000521 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 192/10000
# info: 	 residual: 9.429960e-21
#
# info: [time] Linear solver took 0.0190728 s.
# info: Convergence criterion: |dx|=3.7254e-08, |x|=1.3644e+07, |dx|/|x|=2.7304e-15
# info: [time] Iteration #2 took 0.044386 s.
# info: [time] Solving process #0 took 0.119274 s in time step #102
# info: [time] Time step #102 took 0.12591 s.
# info: [time] Output of timestep 102 took 0.0561582 s.
# info: The whole computation of the time stepping took 102 steps, in which
# 	 the accepted steps are 102, and the rejected steps are 0.
#
# info: [time] Simulation completed. It took 22.2762 s.
# info: OGS completed on 2026-04-14 11:23:21+0200.

# %% [markdown]
# ## Results and visualisation example

# %%
pvd_path = Path("_out_2/BH10_20180718_40.6.pvd")
ms3 = ot.MeshSeries(pvd_path)
pressure=ot.variables.pressure
pressure= pressure.replace(output_unit="MPa")

# %%
y=-40.6
r_st=0.038 #equating the rgeo analytical
r_en=14

coords=np.array(np.geomspace([r_st,y,1e-18],[r_en,y,1e-18],5).round(3)) #extracting along x linearly
ms_probes3 = ms3.probe(points=coords)

labels3 = [f"OGS: r={pt[0]:>5.3f}, y={y}" for pt in coords]
timeogs3=ms_probes3.timevalues
pwsr4p= step_rate_r(pd_lsrf_nb, timeogs3, tp, q_array, ddict, k_val3, r_val3)

diff3 = pwsr4p - ms_probes3['pressure']
# Out:
# 100%|██████████| 103/103 [00:01<00:00, 68.22it/s]

# %% [markdown]
# ### Analytical and Numerical OGS comparison

# %%
fig17, axs= plt.subplots(nrows=1, ncols=2,figsize=[15,8], sharex=True)
ot.plot.line(ms_probes3,"time", pressure,ax=axs[0], color='k',fontsize=18,label=labels3)
axs[0].plot(timeogs3, pwsr4p/1e6,color='tab:red', label=line_labels13) 
axs[1].plot(timeogs3, diff3/1e6, label=line_labels13)

fig17.suptitle("Line-source analytical  - Numerical OGS Nodal") 
axs[1].set_xlabel("time / s")
axs[1].set_ylabel("diff / MPa")

axs[0].legend()
axs[1].legend()
axs[1].grid()
plt.tight_layout()

plt.show()
